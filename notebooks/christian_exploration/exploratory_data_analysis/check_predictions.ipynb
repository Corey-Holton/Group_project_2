# %%
# Import standard library modules
import sys

# Set the relative path to the project root directory
relative_path_to_root = "../../../"

# Add the project root to the system path for importing in-house modules
sys.path.append(relative_path_to_root)

# Import in-house modules from the 'utilities' package
from utilities import print_title, print_label
from utilities import save_data, load_data
from utilities import sp500_data_for_today

# %%
file_names = ["XGB_predict", "lin_reg_predict"]


prediction_data = {}

for file_name in file_names:
    file_path = f"../../../data/raw_data/{file_name}"
    raw_data = load_data(file_path)
    prediction_data[file_name] = raw_data
# Out:
# ╔═══════════════════════════════════════════════════════════════╗
# ║   File `XGB_predict.csv.bz2` loaded from `XGB_predict.zip`    ║
# ╚═══════════════════════════════════════════════════════════════╝
# ╔═══════════════════════════════════════════════════════════════╗
# ║File `lin_reg_predict.csv.bz2` loaded from `lin_reg_predict.zip`║
# ╚═══════════════════════════════════════════════════════════════╝

# %%
import pandas as pd

predictions_df = pd.DataFrame(
    {
        "Date": prediction_data["XGB_predict"]["Date"],
        "Ticker": prediction_data["XGB_predict"]["Ticker"],
        "Adj Close": prediction_data["XGB_predict"]["Adjusted Close"],
        "XGB Predict": prediction_data["XGB_predict"]["Next Day Close"],
        "Lin Reg Predict": prediction_data["lin_reg_predict"]["Next Day Close"]
    },
)

predictions_df.set_index(["Date", "Ticker"], inplace=True)

display(predictions_df.head(20))
display(predictions_df.tail(20))
# Out:
#                    Adj Close  XGB Predict  Lin Reg Predict
# Date       Ticker
# 2024-10-25 A         130.160      130.715          130.281
#            AAPL      231.400      234.897          231.589
#            ABBV      187.820      186.308          187.954
#            ABNB      134.600      134.709          134.727
#            ABT       114.240      114.433          114.330
#            ACGL      105.280      105.343          105.396
#            ACN       360.790      358.028          361.005
#            ADBE      483.730      510.875          484.730
#            ADI       230.170      225.907          230.415
#            ADM        56.570       56.719           56.591
#            ADP       287.960      289.882          288.142
#            ADSK      286.050      288.471          286.088
#            AEE        87.800       87.679           87.843
#            AEP        98.180       98.091           98.258
#            AES        16.965       16.830           16.896
#            AFL       109.710      109.905          109.787
#            AIG        76.820       78.000           76.888
#            AIZ       191.780      193.220          191.935
#            AJG       283.280      287.801          283.617
#            AKAM      101.980      102.128          102.057
#                    Adj Close  XGB Predict  Lin Reg Predict
# Date       Ticker
# 2024-10-25 WBD         7.590        7.527            7.549
#            WDC        69.455       68.667           69.447
#            WEC        97.170       96.751           97.225
#            WELL      130.190      129.877          130.241
#            WFC        64.520       64.547           64.537
#            WM        206.800      208.123          207.080
#            WMB        52.510       53.423           52.497
#            WMT        82.510       83.211           82.560
#            WRB        58.170       58.603           58.224
#            WST       307.920      307.706          308.129
#            WTW       290.410      289.501          290.662
#            WY         31.785       32.556           31.783
#            WYNN       97.980       96.003           98.019
#            XEL        64.460       64.130           64.488
#            XOM       119.510      120.385          119.567
#            XYL       130.410      130.183          130.573
#            YUM       133.040      132.484          133.129
#            ZBH       102.330      102.854          102.496
#            ZBRA      359.970      356.969          360.426
#            ZTS       179.910      184.128          180.158
