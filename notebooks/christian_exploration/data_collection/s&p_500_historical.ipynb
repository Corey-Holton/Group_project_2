# %%
# Import standard library modules
import sys

# Set the relative path to the project root directory
relative_path_to_root = "../../../"

# Add the project root to the system path for importing in-house modules
sys.path.append(relative_path_to_root)

# Import in-house modules from the 'utilities' package
from utilities import print_title, print_label
from utilities import save_data

# %%
# Import libraries for data analysis and visualization
import pandas as pd
import yfinance as yf # Yahoo Finance data retrieval

# %% [markdown]
# ### Data Collection
# ___

# %%
# Fetch S&P 500 tickers

#Get tickers from wikipedia
sp500_tickers = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]['Symbol'].to_numpy()

# Filter out Class B shares that have a '.B' in the ticker name
# Class B shares are typically held by company insiders and have different voting rights than Class A shares
sp500_tickers = [ticker for ticker in sp500_tickers if '.B' not in ticker]

# Total Tickers
print_title("`S&P_500` total tickers: " + str(len(sp500_tickers)))
# Out:
# ╔═══════════════════════════════════════════════════════════════╗
# ║                 `S&P_500` total tickers: 501                  ║
# ╚═══════════════════════════════════════════════════════════════╝

# %%
# Define dates for historical data download
start_date = '2000-01-01'
end_date = '2024-10-14'

try:
    # Download historical prices
    data = yf.download(sp500_tickers, start=start_date, end=end_date)

    # Check if data was successfully downloaded
    downloaded_tickers = data.columns.get_level_values(0).unique()
    print_title(
        f"Successfully downloaded tickers: {len(data.columns.get_level_values(1).unique())} out of {len(sp500_tickers)}", "bright_green", "green")

except Exception as e:
    # Handle any errors that occur during the download
    print_title(
        f"Failed to download data: {str(e)}", "bright_red", "red")
# Out:
# [*********************100%***********************]  501 of 501 completed
# ╔═══════════════════════════════════════════════════════════════╗
# ║        Successfully downloaded tickers: 501 out of 501        ║
# ╚═══════════════════════════════════════════════════════════════╝

# %% [markdown]
# ### Data Cleaning

# %%
# Inspect current dataframe structure
print("Shape:", data.shape)
data.head()
# Out:
# Shape: (6234, 3006)
# Price                      Adj Close                                          \
# Ticker                             A      AAPL ABBV ABNB       ABT      ACGL
# Date
# 2000-01-03 00:00:00+00:00  43.463028  0.844004  NaN  NaN  8.288177  1.277778
# 2000-01-04 00:00:00+00:00  40.142941  0.772846  NaN  NaN  8.051373  1.270833
# 2000-01-05 00:00:00+00:00  37.652866  0.784155  NaN  NaN  8.036573  1.388889
# 2000-01-06 00:00:00+00:00  36.219189  0.716296  NaN  NaN  8.317780  1.375000
# 2000-01-07 00:00:00+00:00  39.237465  0.750226  NaN  NaN  8.406585  1.451389
#
# Price                                                          ... Volume  \
# Ticker                    ACN       ADBE        ADI       ADM  ...    WTW
# Date                                                           ...
# 2000-01-03 00:00:00+00:00 NaN  16.274673  28.214645  6.307346  ...    NaN
# 2000-01-04 00:00:00+00:00 NaN  14.909400  26.787298  6.241645  ...    NaN
# 2000-01-05 00:00:00+00:00 NaN  15.204175  27.178368  6.143093  ...    NaN
# 2000-01-06 00:00:00+00:00 NaN  15.328291  26.435347  6.175945  ...    NaN
# 2000-01-07 00:00:00+00:00 NaN  16.072989  27.178368  6.274496  ...    NaN
#
# Price                                                                        \
# Ticker                          WY WYNN      XEL       XOM XYL      YUM ZBH
# Date
# 2000-01-03 00:00:00+00:00   973700  NaN  2738600  13458200 NaN  3033493 NaN
# 2000-01-04 00:00:00+00:00  1201700  NaN   425200  14510800 NaN  3315031 NaN
# 2000-01-05 00:00:00+00:00  1184600  NaN   500200  17485000 NaN  4642602 NaN
# 2000-01-06 00:00:00+00:00  1307700  NaN   344100  19461600 NaN  3947658 NaN
# 2000-01-07 00:00:00+00:00  1728000  NaN   469500  16603800 NaN  6063647 NaN
#
# Price
# Ticker                        ZBRA ZTS
# Date
# 2000-01-03 00:00:00+00:00  1055700 NaN
# 2000-01-04 00:00:00+00:00   522450 NaN
# 2000-01-05 00:00:00+00:00   612225 NaN
# 2000-01-06 00:00:00+00:00   263925 NaN
# 2000-01-07 00:00:00+00:00   333900 NaN
#
# [5 rows x 3006 columns]

# %%
# Remove `Close`, `High`, `Low`, `Open`, `Volume` columns
# Keep only `Adj Close` for each ticker

# The closing price adjusted for corporate actions like stock splits and dividends. 
# It’s the most accurate reflection of the stock’s value for historical analysis.
data_clean = data['Adj Close']

print("Shape:", data_clean.shape)
data_clean.head()
# Out:
# Shape: (6234, 501)
# Ticker                             A      AAPL  ABBV  ABNB       ABT  \
# Date
# 2000-01-03 00:00:00+00:00  43.463028  0.844004   NaN   NaN  8.288177
# 2000-01-04 00:00:00+00:00  40.142941  0.772846   NaN   NaN  8.051373
# 2000-01-05 00:00:00+00:00  37.652866  0.784155   NaN   NaN  8.036573
# 2000-01-06 00:00:00+00:00  36.219189  0.716296   NaN   NaN  8.317780
# 2000-01-07 00:00:00+00:00  39.237465  0.750226   NaN   NaN  8.406585
#
# Ticker                         ACGL  ACN       ADBE        ADI       ADM  ...  \
# Date                                                                      ...
# 2000-01-03 00:00:00+00:00  1.277778  NaN  16.274673  28.214645  6.307346  ...
# 2000-01-04 00:00:00+00:00  1.270833  NaN  14.909400  26.787298  6.241645  ...
# 2000-01-05 00:00:00+00:00  1.388889  NaN  15.204175  27.178368  6.143093  ...
# 2000-01-06 00:00:00+00:00  1.375000  NaN  15.328291  26.435347  6.175945  ...
# 2000-01-07 00:00:00+00:00  1.451389  NaN  16.072989  27.178368  6.274496  ...
#
# Ticker                     WTW         WY  WYNN       XEL        XOM  XYL  \
# Date
# 2000-01-03 00:00:00+00:00  NaN  11.352946   NaN  6.848378  18.035816  NaN
# 2000-01-04 00:00:00+00:00  NaN  10.926450   NaN  7.006071  17.690359  NaN
# 2000-01-05 00:00:00+00:00  NaN  11.505266   NaN  7.276401  18.654768  NaN
# 2000-01-06 00:00:00+00:00  NaN  12.043468   NaN  7.208816  19.619181  NaN
# 2000-01-07 00:00:00+00:00  NaN  11.647433   NaN  7.208816  19.561602  NaN
#
# Ticker                          YUM  ZBH       ZBRA  ZTS
# Date
# 2000-01-03 00:00:00+00:00  4.634289  NaN  25.027779  NaN
# 2000-01-04 00:00:00+00:00  4.541137  NaN  24.666668  NaN
# 2000-01-05 00:00:00+00:00  4.564423  NaN  25.138889  NaN
# 2000-01-06 00:00:00+00:00  4.525610  NaN  23.777779  NaN
# 2000-01-07 00:00:00+00:00  4.424698  NaN  23.513889  NaN
#
# [5 rows x 501 columns]

# %% [markdown]
# ### Impute missing values (NA's)

# %%
# Check for missing values in each column

print_title("Missing values in each column", closed_corners=False)
missing_values = data_clean.isnull().sum()

for index, value in missing_values.items():
    if value > 0:
        print_label(f"{index}", f"{value}")
# Out:
# ╔═══════════════════════════════════════════════════════════════╗
# ║                 Missing values in each column                 ║
# ╠═══════════════════════════════════════════════════════════════╣
# ║ ABBV                           |             3269             ║
# ║ ABNB                           |             5269             ║
# ║ ACN                            |             389              ║
# ║ AIZ                            |             1027             ║
# ║ ALGN                           |             271              ║
# ║ ALLE                           |             3491             ║
# ║ AMCR                           |             3111             ║
# ║ AMP                            |             1433             ║
# ║ AMTM                           |             6220             ║
# ║ ANET                           |             3628             ║
# ║ APTV                           |             2989             ║
# ║ AVGO                           |             2412             ║
# ║ AWK                            |             2087             ║
# ║ AXON                           |             368              ║
# ║ BG                             |             399              ║
# ║ BLDR                           |             1378             ║
# ║ BR                             |             1813             ║
# ║ BX                             |             1877             ║
# ║ CARR                           |             5084             ║
# ║ CBOE                           |             2627             ║
# ║ CBRE                           |             1114             ║
# ║ CDW                            |             3391             ║
# ║ CE                             |             1269             ║
# ║ CEG                            |             5547             ║
# ║ CF                             |             1409             ║
# ║ CFG                            |             3704             ║
# ║ CHTR                           |             2516             ║
# ║ CME                            |             735              ║
# ║ CMG                            |             1524             ║
# ║ CNC                            |             488              ║
# ║ CPAY                           |             2755             ║
# ║ CRL                            |             120              ║
# ║ CRM                            |             1122             ║
# ║ CRWD                           |             4890             ║
# ║ CTLT                           |             3666             ║
# ║ CTVA                           |             4878             ║
# ║ CZR                            |             3702             ║
# ║ DAL                            |             1842             ║
# ║ DAY                            |             4607             ║
# ║ DELL                           |             4182             ║
# ║ DFS                            |             1871             ║
# ║ DG                             |             2482             ║
# ║ DLR                            |             1212             ║
# ║ DOW                            |             4832             ║
# ║ DPZ                            |             1135             ║
# ║ DXCM                           |             1326             ║
# ║ ELV                            |             457              ║
# ║ ENPH                           |             3080             ║
# ║ EPAM                           |             3044             ║
# ║ EQIX                           |             154              ║
# ║ EW                             |              58              ║
# ║ EXPE                           |             1394             ║
# ║ EXR                            |             1159             ║
# ║ FANG                           |             3216             ║
# ║ FIS                            |             369              ║
# ║ FOX                            |             4827             ║
# ║ FOXA                           |             4826             ║
# ║ FSLR                           |             1730             ║
# ║ FTNT                           |             2485             ║
# ║ FTV                            |             4151             ║
# ║ GDDY                           |             3833             ║
# ║ GEHC                           |             5776             ║
# ║ GEV                            |             6098             ║
# ║ GM                             |             2737             ║
# ║ GNRC                           |             2542             ║
# ║ GOOG                           |             1162             ║
# ║ GOOGL                          |             1162             ║
# ║ GPN                            |             261              ║
# ║ GRMN                           |             237              ║
# ║ HCA                            |             2813             ║
# ║ HII                            |             2821             ║
# ║ HLT                            |             3508             ║
# ║ HPE                            |             3973             ║
# ║ HWM                            |             4235             ║
# ║ ICE                            |             1477             ║
# ║ INVH                           |             4297             ║
# ║ IQV                            |             3357             ║
# ║ IR                             |             4367             ║
# ║ ISRG                           |             115              ║
# ║ KDP                            |             2097             ║
# ║ KEYS                           |             3722             ║
# ║ KHC                            |             3899             ║
# ║ KKR                            |             2648             ║
# ║ KMI                            |             2795             ║
# ║ KVUE                           |             5871             ║
# ║ LDOS                           |             1707             ║
# ║ LKQ                            |             943              ║
# ║ LULU                           |             1901             ║
# ║ LVS                            |             1244             ║
# ║ LW                             |             4242             ║
# ║ LYB                            |             2594             ║
# ║ LYV                            |             1501             ║
# ║ MA                             |             1607             ║
# ║ MDLZ                           |             364              ║
# ║ MET                            |              65              ║
# ║ META                           |             3114             ║
# ║ MKTX                           |             1217             ║
# ║ MOH                            |             877              ║
# ║ MPC                            |             2887             ║
# ║ MPWR                           |             1227             ║
# ║ MRNA                           |             4763             ║
# ║ MSCI                           |             1979             ║
# ║ NCLH                           |             3281             ║
# ║ NDAQ                           |             624              ║
# ║ NFLX                           |             598              ║
# ║ NOW                            |             3143             ║
# ║ NRG                            |             983              ║
# ║ NWS                            |             3385             ║
# ║ NWSA                           |             3385             ║
# ║ NXPI                           |             2664             ║
# ║ ON                             |              83              ║
# ║ OTIS                           |             5084             ║
# ║ PANW                           |             3157             ║
# ║ PARA                           |             1489             ║
# ║ PAYC                           |             3592             ║
# ║ PFG                            |             452              ║
# ║ PKG                            |              18              ║
# ║ PLTR                           |             5219             ║
# ║ PM                             |             2061             ║
# ║ PODD                           |             1850             ║
# ║ PRU                            |             488              ║
# ║ PSX                            |             3088             ║
# ║ PYPL                           |             3899             ║
# ║ QRVO                           |             3773             ║
# ║ SMCI                           |             1818             ║
# ║ SOLV                           |             6098             ║
# ║ STX                            |             738              ║
# ║ SW                             |             6165             ║
# ║ SYF                            |             3666             ║
# ║ TDG                            |             1557             ║
# ║ TEL                            |             1871             ║
# ║ TMUS                           |             1832             ║
# ║ TPR                            |             193              ║
# ║ TRGP                           |             2749             ║
# ║ TSLA                           |             2637             ║
# ║ UAL                            |             1531             ║
# ║ UBER                           |             4868             ║
# ║ ULTA                           |             1964             ║
# ║ V                              |             2063             ║
# ║ VICI                           |             4528             ║
# ║ VLTO                           |             5976             ║
# ║ VRSK                           |             2455             ║
# ║ VST                            |             4216             ║
# ║ WBD                            |             1385             ║
# ║ WTW                            |             363              ║
# ║ WYNN                           |             706              ║
# ║ XYL                            |             2964             ║
# ║ ZBH                            |             393              ║
# ║ ZTS                            |             3290             ║

# %%
# Impute missing values with 0

# Fill missing values with 0
data_clean = data_clean.fillna(0)

# Confirm that there are no missing values
print("Number of NA's:", data_clean.isnull().sum().sum())
# Out:
# Number of NA's: 0

# %% [markdown]
# ### Inspect dataset structure

# %%
print("Shape:", data_clean.shape)
data_clean.head()
# Out:
# Shape: (6234, 501)
# Ticker                             A      AAPL  ABBV  ABNB       ABT  \
# Date
# 2000-01-03 00:00:00+00:00  43.463028  0.844004   0.0   0.0  8.288177
# 2000-01-04 00:00:00+00:00  40.142941  0.772846   0.0   0.0  8.051373
# 2000-01-05 00:00:00+00:00  37.652866  0.784155   0.0   0.0  8.036573
# 2000-01-06 00:00:00+00:00  36.219189  0.716296   0.0   0.0  8.317780
# 2000-01-07 00:00:00+00:00  39.237465  0.750226   0.0   0.0  8.406585
#
# Ticker                         ACGL  ACN       ADBE        ADI       ADM  ...  \
# Date                                                                      ...
# 2000-01-03 00:00:00+00:00  1.277778  0.0  16.274673  28.214645  6.307346  ...
# 2000-01-04 00:00:00+00:00  1.270833  0.0  14.909400  26.787298  6.241645  ...
# 2000-01-05 00:00:00+00:00  1.388889  0.0  15.204175  27.178368  6.143093  ...
# 2000-01-06 00:00:00+00:00  1.375000  0.0  15.328291  26.435347  6.175945  ...
# 2000-01-07 00:00:00+00:00  1.451389  0.0  16.072989  27.178368  6.274496  ...
#
# Ticker                     WTW         WY  WYNN       XEL        XOM  XYL  \
# Date
# 2000-01-03 00:00:00+00:00  0.0  11.352946   0.0  6.848378  18.035816  0.0
# 2000-01-04 00:00:00+00:00  0.0  10.926450   0.0  7.006071  17.690359  0.0
# 2000-01-05 00:00:00+00:00  0.0  11.505266   0.0  7.276401  18.654768  0.0
# 2000-01-06 00:00:00+00:00  0.0  12.043468   0.0  7.208816  19.619181  0.0
# 2000-01-07 00:00:00+00:00  0.0  11.647433   0.0  7.208816  19.561602  0.0
#
# Ticker                          YUM  ZBH       ZBRA  ZTS
# Date
# 2000-01-03 00:00:00+00:00  4.634289  0.0  25.027779  0.0
# 2000-01-04 00:00:00+00:00  4.541137  0.0  24.666668  0.0
# 2000-01-05 00:00:00+00:00  4.564423  0.0  25.138889  0.0
# 2000-01-06 00:00:00+00:00  4.525610  0.0  23.777779  0.0
# 2000-01-07 00:00:00+00:00  4.424698  0.0  23.513889  0.0
#
# [5 rows x 501 columns]

# %%
# Reset index to make the date a column in the dataframe
data_clean = data_clean.reset_index()

# %% [markdown]
# ### Save dataset

# %%
# Export to a new CSV file
file_name = f"sp500_adj_close_{start_date}_{end_date}.zip"
file_path = f"../../../data/raw_data/{file_name}"

save_data(data_clean, file_path)
# Out:
# ╔═══════════════════════════════════════════════════════════════╗
# ║   File saved as `sp500_adj_close_2000-01-01_2024-10-14.csv`   ║
# ╚═══════════════════════════════════════════════════════════════╝
