# %%
# Import standard library modules
import sys

# Set the relative path to the project root directory
relative_path_to_root = "../../../"

# Add the project root to the system path for importing in-house modules
sys.path.append(relative_path_to_root)

# Import in-house modules from the 'utilities' package
from utilities import split_dataset_by_date, clean_historical_data, check_tickers_for_missing_values
from utilities import calc_vif, calc_p_values, calc_correlation, highlight_vif, highlight_p_values, evaluate_regression_model, evaluate_cross_validation
from utilities import load_data, save_data

# %%
# Data manipulation and analysis
import pandas as pd

# Date and time manipulation
from datetime import date

# File and directory manipulation
from pathlib import Path

# Data preprocessing and model selection
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler

# Machine learning models (regression)
from sklearn.linear_model import LinearRegression

# %%
file_name = "sp500_adj_close_raw_with_nas"
file_path = f"../../../data/raw_data/{file_name}"

raw_data = load_data(file_path)
# Out:
# ╔═══════════════════════════════════════════════════════════════╗
# ║File `test_w_na.csv.bz2` loaded from `sp500_adj_close_raw_with_nas.zip`║
# ╚═══════════════════════════════════════════════════════════════╝

# %% [markdown]
# ### Data Pre-Processing
# ___

# %% [markdown]
# #### Split todays data (For prediction) and historical data (For training)

# %%
todays_date = "2024-10-25"

historical_data, todays_data = split_dataset_by_date(raw_data, todays_date)

print("Todays Date:", todays_date)
# Out:
# Todays Date: 2024-10-25

# %% [markdown]
# #### Ensure Missing Values on Todays Data is what we are Predicting

# %%
todays_data.isnull().sum()
# Out:
# Date                    0
# Ticker                  0
# Adjusted Close          0
# Next Day Close        501
# Previous Day Close      0
# Return                  0
# Volatility              0
# RSI                     0
# SMA_50                  0
# SMA_100                 0
# SMA_200                 0
# Upper Band              0
# Lower Band              0
# Support                 0
# Resistance              0
# Action                501
# dtype: int64

# %% [markdown]
# #### Handle Missing Values (NA's)

# %%
historical_data = clean_historical_data(historical_data)

historical_data.isnull().sum()
# Out:
# Date                  0
# Ticker                0
# Adjusted Close        0
# Next Day Close        0
# Previous Day Close    0
# Return                0
# Volatility            0
# RSI                   0
# SMA_50                0
# SMA_100               0
# SMA_200               0
# Upper Band            0
# Lower Band            0
# Support               0
# Resistance            0
# Action                0
# dtype: int64

# %%
tickers_no_missing_values, tickers_with_missing_values = check_tickers_for_missing_values(historical_data)
# Out:
# ╔═══════════════════════════════════════════════════════════════╗
# ║          Tickers that do not have any missing values          ║
# ╠═══════════════════════════════════════════════════════════════╣
# ║ Number of unique tickers:      |          501.00000           ║
# ║ Number of tickers with no m... |          501.00000           ║
# ║ Number of tickers with miss... |           0.00000            ║
# ╚═══════════════════════════════════════════════════════════════╝

# %% [markdown]
# ### Exploratory Data Analysis (EDA):
# ___

# %% [markdown]
# #### Todays Data:

# %%
print("Shape:", todays_data.shape)
# Out:
# Shape: (501, 16)

# %% [markdown]
# #### Historical Data:

# %%
print("Shape:", historical_data.shape)
# Out:
# Shape: (1978479, 16)

# %% [markdown]
# #### Inspect Tickers Individually

# %%
# Inspect Cleaned data zeroing in on individual tickers
select_df = raw_data.copy()

select_ticker = select_df["Ticker"] == "AAPL"

select_df[select_ticker]
# Out:
#                Date Ticker  Adjusted Close  Next Day Close  \
# 1        2008-01-02   AAPL        5.876342        5.879055
# 502      2008-01-03   AAPL        5.879055        5.430276
# 1003     2008-01-04   AAPL        5.430276        5.357593
# 1504     2008-01-07   AAPL        5.357593        5.164871
# 2005     2008-01-08   AAPL        5.164871        5.410674
# ...             ...    ...             ...             ...
# 2118730  2024-10-21   AAPL      236.480000      235.860000
# 2119231  2024-10-22   AAPL      235.860000      230.760000
# 2119732  2024-10-23   AAPL      230.760000      230.570000
# 2120233  2024-10-24   AAPL      230.570000      231.400000
# 2120734  2024-10-25   AAPL      231.400000             NaN
#
#          Previous Day Close    Return  Volatility        RSI      SMA_50  \
# 1                  5.974057 -0.016357    0.018937  59.067350    5.518483
# 502                5.876342  0.000462    0.018287  56.259520    5.530891
# 1003               5.879055 -0.076335    0.025363  37.311500    5.527205
# 1504               5.430276 -0.013385    0.024475  36.547832    5.522205
# 2005               5.357593 -0.035972    0.024816  36.241930    5.515250
# ...                     ...       ...         ...        ...         ...
# 2118730          235.000000  0.006298    0.012880  66.655846  225.934400
# 2119231          236.480000 -0.002622    0.012744  64.702080  226.301000
# 2119732          235.860000 -0.021623    0.013733  57.298534  226.490800
# 2120233          230.760000 -0.000823    0.013688  55.555565  226.667800
# 2120734          230.570000  0.003600    0.013669  66.374374  226.801400
#
#             SMA_100     SMA_200  Upper Band  Lower Band     Support  \
# 1          4.939064    4.197630    6.135833    5.403559    4.637376
# 502        4.960155    4.213231    6.122779    5.462215    4.637376
# 1003       4.975917    4.226226    6.142305    5.426252    4.637376
# 1504       4.992085    4.238845    6.171195    5.360235    4.637376
# 2005       5.007573    4.250567    6.214129    5.247783    4.637376
# ...             ...         ...         ...         ...         ...
# 2118730  220.221050  199.802290  236.515660  221.650340  216.320000
# 2119231  220.668960  200.079120  237.478500  221.536500  216.320000
# 2119732  221.056290  200.308620  237.575040  221.878950  216.320000
# 2120233  221.423930  200.539280  237.665250  222.093750  216.320000
# 2120734  221.796680  200.768840  237.809080  222.310910  216.320000
#
#          Resistance Action
# 1           6.02684    buy
# 502         6.02684   sell
# 1003        6.02684  short
# 1504        6.02684  short
# 2005        6.02684    buy
# ...             ...    ...
# 2118730   236.48000   sell
# 2119231   236.48000  short
# 2119732   236.48000  short
# 2120233   236.48000    buy
# 2120734   236.48000    NaN
#
# [4234 rows x 16 columns]

# %% [markdown]
# ### Create Multiple Versions of Dataset
# ___

# %%
# Data with dates and without tickers (Set as index for reference)
def prepare_data_v2(main_data: pd.DataFrame) -> pd.DataFrame:
    # Create a copy of the input DataFrame
    df = main_data.copy().reset_index(drop=True)
    
    # Convert the `Date` column to datetime
    df["Date"] = pd.to_datetime(df["Date"])
    
    # Extract year, month, and day from the `Date` column
    df["Year"] = df["Date"].dt.year
    df["Month"] = df["Date"].dt.month
    df["Day"] = df["Date"].dt.day
    
    # Set the index to `Date` and `Ticker`
    df = df.set_index(["Date", "Ticker"])
    
    return df

main_data = prepare_data_v2(historical_data.copy().reset_index(drop=True))

# %% [markdown]
# #### Select which version of the data to work with

# %%
select_data = main_data.copy()

select_columns_to_drop = ["Action", "Previous Day Close", "SMA_50", "Resistance", "Upper Band", "SMA_200"]

data = select_data.drop(columns=select_columns_to_drop)

print("Shape:", data.shape)
data.head()
# Out:
# Shape: (1978479, 11)
#                    Adjusted Close  Next Day Close    Return  Volatility  \
# Date       Ticker
# 2008-01-02 A            23.256388       23.025743 -0.011976    0.015704
#            AAPL          5.876342        5.879055 -0.016357    0.018937
#            ABT          18.130209       18.019754 -0.006055    0.010484
#            ACGL          7.608889        7.764444 -0.026581    0.016022
#            ACN          26.437077       25.982521  0.000833    0.024039
#
#                          RSI    SMA_100  Lower Band    Support  Year  Month  \
# Date       Ticker
# 2008-01-02 A       48.827590  23.299887   22.540236  21.392029  2008      1
#            AAPL    59.067350   4.939064    5.403559   4.637376  2008      1
#            ABT     34.677372  17.628250   18.221804  16.775562  2008      1
#            ACGL    45.154190   7.878933    7.378535   7.463333  2008      1
#            ACN     54.812176  27.784420   24.273775  24.765512  2008      1
#
#                    Day
# Date       Ticker
# 2008-01-02 A         2
#            AAPL      2
#            ABT       2
#            ACGL      2
#            ACN       2

# %% [markdown]
# ### Split data features `X` and target `y`
# ___

# %%
# Split the data into features (X) and target (y)
X = data.drop(columns="Next Day Close")

y = data["Next Day Close"]

print("Shape of X:", X.shape)
print("Shape of y:", y.shape)
# Out:
# Shape of X: (1978479, 10)
# Shape of y: (1978479,)

# %% [markdown]
# ### Feature Engineering
# ___

# %% [markdown]
# #### Inspect Multicollinearity using VIF

# %%
# Perform correlation matrix of X
calc_correlation(X)
# Out:
# <style type="text/css">
# #T_dc94d_row0_col0, #T_dc94d_row0_col5, #T_dc94d_row0_col6, #T_dc94d_row1_col1, #T_dc94d_row2_col2, #T_dc94d_row3_col3, #T_dc94d_row4_col4, #T_dc94d_row4_col6, #T_dc94d_row5_col0, #T_dc94d_row5_col5, #T_dc94d_row5_col6, #T_dc94d_row6_col0, #T_dc94d_row6_col4, #T_dc94d_row6_col5, #T_dc94d_row6_col6, #T_dc94d_row7_col7, #T_dc94d_row8_col8, #T_dc94d_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_dc94d_row0_col1, #T_dc94d_row3_col9, #T_dc94d_row8_col1 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_dc94d_row0_col2 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_dc94d_row0_col3 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_dc94d_row0_col4, #T_dc94d_row4_col0, #T_dc94d_row4_col5, #T_dc94d_row5_col4 {
#   background-color: #b50927;
#   color: #f1f1f1;
# }
# #T_dc94d_row0_col7, #T_dc94d_row5_col7, #T_dc94d_row6_col7 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_dc94d_row0_col8, #T_dc94d_row4_col8, #T_dc94d_row5_col8, #T_dc94d_row6_col8 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_dc94d_row0_col9, #T_dc94d_row1_col9, #T_dc94d_row2_col0, #T_dc94d_row2_col3, #T_dc94d_row2_col4, #T_dc94d_row2_col5, #T_dc94d_row2_col6, #T_dc94d_row2_col7, #T_dc94d_row2_col9, #T_dc94d_row4_col1, #T_dc94d_row4_col9, #T_dc94d_row5_col1, #T_dc94d_row5_col9, #T_dc94d_row6_col1, #T_dc94d_row6_col9, #T_dc94d_row7_col1, #T_dc94d_row7_col2, #T_dc94d_row7_col8, #T_dc94d_row7_col9, #T_dc94d_row8_col9, #T_dc94d_row9_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_dc94d_row1_col0, #T_dc94d_row1_col5, #T_dc94d_row1_col6, #T_dc94d_row8_col0 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_dc94d_row1_col2 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_dc94d_row1_col3 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_dc94d_row1_col4, #T_dc94d_row2_col8, #T_dc94d_row3_col2, #T_dc94d_row3_col4, #T_dc94d_row9_col4 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_dc94d_row1_col7 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_dc94d_row1_col8, #T_dc94d_row2_col1 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_dc94d_row3_col0, #T_dc94d_row5_col2, #T_dc94d_row6_col2 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_dc94d_row3_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_dc94d_row3_col5 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_dc94d_row3_col6, #T_dc94d_row8_col5, #T_dc94d_row8_col6 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_dc94d_row3_col7 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_dc94d_row3_col8, #T_dc94d_row9_col8 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_dc94d_row4_col2, #T_dc94d_row4_col3 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_dc94d_row4_col7 {
#   background-color: #b1cbfc;
#   color: #000000;
# }
# #T_dc94d_row5_col3, #T_dc94d_row7_col3, #T_dc94d_row8_col7 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_dc94d_row6_col3, #T_dc94d_row9_col3 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_dc94d_row7_col0 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_dc94d_row7_col4 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_dc94d_row7_col5 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_dc94d_row7_col6 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_dc94d_row8_col2 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_dc94d_row8_col3 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_dc94d_row8_col4 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_dc94d_row9_col0 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_dc94d_row9_col2, #T_dc94d_row9_col7 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_dc94d_row9_col5, #T_dc94d_row9_col6 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_dc94d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dc94d_level0_col0" class="col_heading level0 col0" >Adjusted Close</th>
#       <th id="T_dc94d_level0_col1" class="col_heading level0 col1" >Return</th>
#       <th id="T_dc94d_level0_col2" class="col_heading level0 col2" >Volatility</th>
#       <th id="T_dc94d_level0_col3" class="col_heading level0 col3" >RSI</th>
#       <th id="T_dc94d_level0_col4" class="col_heading level0 col4" >SMA_100</th>
#       <th id="T_dc94d_level0_col5" class="col_heading level0 col5" >Lower Band</th>
#       <th id="T_dc94d_level0_col6" class="col_heading level0 col6" >Support</th>
#       <th id="T_dc94d_level0_col7" class="col_heading level0 col7" >Year</th>
#       <th id="T_dc94d_level0_col8" class="col_heading level0 col8" >Month</th>
#       <th id="T_dc94d_level0_col9" class="col_heading level0 col9" >Day</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc94d_level0_row0" class="row_heading level0 row0" >Adjusted Close</th>
#       <td id="T_dc94d_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_dc94d_row0_col1" class="data row0 col1" >0.004575</td>
#       <td id="T_dc94d_row0_col2" class="data row0 col2" >-0.049952</td>
#       <td id="T_dc94d_row0_col3" class="data row0 col3" >0.023530</td>
#       <td id="T_dc94d_row0_col4" class="data row0 col4" >0.995365</td>
#       <td id="T_dc94d_row0_col5" class="data row0 col5" >0.998308</td>
#       <td id="T_dc94d_row0_col6" class="data row0 col6" >0.996711</td>
#       <td id="T_dc94d_row0_col7" class="data row0 col7" >0.259818</td>
#       <td id="T_dc94d_row0_col8" class="data row0 col8" >0.004643</td>
#       <td id="T_dc94d_row0_col9" class="data row0 col9" >0.000054</td>
#     </tr>
#     <tr>
#       <th id="T_dc94d_level0_row1" class="row_heading level0 row1" >Return</th>
#       <td id="T_dc94d_row1_col0" class="data row1 col0" >0.004575</td>
#       <td id="T_dc94d_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_dc94d_row1_col2" class="data row1 col2" >0.026863</td>
#       <td id="T_dc94d_row1_col3" class="data row1 col3" >0.214930</td>
#       <td id="T_dc94d_row1_col4" class="data row1 col4" >-0.001790</td>
#       <td id="T_dc94d_row1_col5" class="data row1 col5" >-0.002142</td>
#       <td id="T_dc94d_row1_col6" class="data row1 col6" >-0.001604</td>
#       <td id="T_dc94d_row1_col7" class="data row1 col7" >0.001578</td>
#       <td id="T_dc94d_row1_col8" class="data row1 col8" >0.002862</td>
#       <td id="T_dc94d_row1_col9" class="data row1 col9" >-0.000203</td>
#     </tr>
#     <tr>
#       <th id="T_dc94d_level0_row2" class="row_heading level0 row2" >Volatility</th>
#       <td id="T_dc94d_row2_col0" class="data row2 col0" >-0.049952</td>
#       <td id="T_dc94d_row2_col1" class="data row2 col1" >0.026863</td>
#       <td id="T_dc94d_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_dc94d_row2_col3" class="data row2 col3" >-0.095813</td>
#       <td id="T_dc94d_row2_col4" class="data row2 col4" >-0.039082</td>
#       <td id="T_dc94d_row2_col5" class="data row2 col5" >-0.059477</td>
#       <td id="T_dc94d_row2_col6" class="data row2 col6" >-0.057813</td>
#       <td id="T_dc94d_row2_col7" class="data row2 col7" >-0.137810</td>
#       <td id="T_dc94d_row2_col8" class="data row2 col8" >0.008778</td>
#       <td id="T_dc94d_row2_col9" class="data row2 col9" >-0.003205</td>
#     </tr>
#     <tr>
#       <th id="T_dc94d_level0_row3" class="row_heading level0 row3" >RSI</th>
#       <td id="T_dc94d_row3_col0" class="data row3 col0" >0.023530</td>
#       <td id="T_dc94d_row3_col1" class="data row3 col1" >0.214930</td>
#       <td id="T_dc94d_row3_col2" class="data row3 col2" >-0.095813</td>
#       <td id="T_dc94d_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_dc94d_row3_col4" class="data row3 col4" >0.000401</td>
#       <td id="T_dc94d_row3_col5" class="data row3 col5" >0.007452</td>
#       <td id="T_dc94d_row3_col6" class="data row3 col6" >0.004387</td>
#       <td id="T_dc94d_row3_col7" class="data row3 col7" >0.011158</td>
#       <td id="T_dc94d_row3_col8" class="data row3 col8" >-0.002540</td>
#       <td id="T_dc94d_row3_col9" class="data row3 col9" >0.003985</td>
#     </tr>
#     <tr>
#       <th id="T_dc94d_level0_row4" class="row_heading level0 row4" >SMA_100

# %% [markdown]
# ##### **Note: It is recommended to remove `["Previous Day Close", "Resistance", "Upper Band", "SMA_50", "SMA_200"]` after VIF inspection...**

# %%
# Perform Variance Inflation Factor (VIF) analysis
vif = calc_vif(X)

vif.style.apply(lambda x: highlight_vif(x, threshold=2000))
# Out:
# <style type="text/css">
# #T_6c07e_row0_col0, #T_6c07e_row1_col0, #T_6c07e_row2_col0, #T_6c07e_row3_col0, #T_6c07e_row4_col0, #T_6c07e_row5_col0, #T_6c07e_row6_col0, #T_6c07e_row7_col0, #T_6c07e_row8_col0, #T_6c07e_row9_col0 {
#   background-color: black;
# }
# </style>
# <table id="T_6c07e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c07e_level0_col0" class="col_heading level0 col0" >VIF</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c07e_level0_row0" class="row_heading level0 row0" >Return</th>
#       <td id="T_6c07e_row0_col0" class="data row0 col0" >1.055047</td>
#     </tr>
#     <tr>
#       <th id="T_6c07e_level0_row1" class="row_heading level0 row1" >Volatility</th>
#       <td id="T_6c07e_row1_col0" class="data row1 col0" >3.424442</td>
#     </tr>
#     <tr>
#       <th id="T_6c07e_level0_row2" class="row_heading level0 row2" >Day</th>
#       <td id="T_6c07e_row2_col0" class="data row2 col0" >4.226557</td>
#     </tr>
#     <tr>
#       <th id="T_6c07e_level0_row3" class="row_heading level0 row3" >Month</th>
#       <td id="T_6c07e_row3_col0" class="data row3 col0" >4.641133</td>
#     </tr>
#     <tr>
#       <th id="T_6c07e_level0_row4" class="row_heading level0 row4" >RSI</th>
#       <td id="T_6c07e_row4_col0" class="data row4 col0" >13.036789</td>
#     </tr>
#     <tr>
#       <th id="T_6c07e_level0_row5" class="row_heading level0 row5" >Year</th>
#       <td id="T_6c07e_row5_col0" class="data row5 col0" >23.556780</td>
#     </tr>
#     <tr>
#       <th id="T_6c07e_level0_row6" class="row_heading level0 row6" >SMA_100</th>
#       <td id="T_6c07e_row6_col0" class="data row6 col0" >236.750592</td>
#     </tr>
#     <tr>
#       <th id="T_6c07e_level0_row7" class="row_heading level0 row7" >Adjusted Close</th>
#       <td id="T_6c07e_row7_col0" class="data row7 col0" >438.247347</td>
#     </tr>
#     <tr>
#       <th id="T_6c07e_level0_row8" class="row_heading level0 row8" >Support</th>
#       <td id="T_6c07e_row8_col0" class="data row8 col0" >467.769801</td>
#     </tr>
#     <tr>
#       <th id="T_6c07e_level0_row9" class="row_heading level0 row9" >Lower Band</th>
#       <td id="T_6c07e_row9_col0" class="data row9 col0" >620.094715</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Data Splitting
# ___

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2, # 80% training and 20% testing
    random_state=42
)

print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (1582783, 10)
# Shape of X_test: (395696, 10)
# Shape of y_train: (1582783,)
# Shape of y_test: (395696,)

# %% [markdown]
# #### Inspect Probability Values `(p-values)`|

# %% [markdown]
# ##### **Note: It is recommended to remove `["Day"]` after p-value inspection...**

# %%
# Check P-Values
import statsmodels.api as sm

p_values, ols_model = calc_p_values(X_train, y_train)

p_values.style.apply(highlight_p_values)
# Out:
# <style type="text/css">
# #T_d292f_row0_col0, #T_d292f_row1_col0, #T_d292f_row2_col0, #T_d292f_row3_col0, #T_d292f_row4_col0, #T_d292f_row5_col0, #T_d292f_row6_col0, #T_d292f_row7_col0, #T_d292f_row8_col0 {
#   background-color: black;
# }
# </style>
# <table id="T_d292f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d292f_level0_col0" class="col_heading level0 col0" >p_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d292f_level0_row0" class="row_heading level0 row0" >Adjusted Close</th>
#       <td id="T_d292f_row0_col0" class="data row0 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d292f_level0_row1" class="row_heading level0 row1" >SMA_100</th>
#       <td id="T_d292f_row1_col0" class="data row1 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d292f_level0_row2" class="row_heading level0 row2" >Lower Band</th>
#       <td id="T_d292f_row2_col0" class="data row2 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d292f_level0_row3" class="row_heading level0 row3" >Support</th>
#       <td id="T_d292f_row3_col0" class="data row3 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d292f_level0_row4" class="row_heading level0 row4" >Year</th>
#       <td id="T_d292f_row4_col0" class="data row4 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d292f_level0_row5" class="row_heading level0 row5" >RSI</th>
#       <td id="T_d292f_row5_col0" class="data row5 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d292f_level0_row6" class="row_heading level0 row6" >Return</th>
#       <td id="T_d292f_row6_col0" class="data row6 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d292f_level0_row7" class="row_heading level0 row7" >Volatility</th>
#       <td id="T_d292f_row7_col0" class="data row7 col0" >0.000003</td>
#     </tr>
#     <tr>
#       <th id="T_d292f_level0_row8" class="row_heading level0 row8" >Month</th>
#       <td id="T_d292f_row8_col0" class="data row8 col0" >0.000131</td>
#     </tr>
#     <tr>
#       <th id="T_d292f_level0_row9" class="row_heading level0 row9" >Day</th>
#       <td id="T_d292f_row9_col0" class="data row9 col0" >0.482955</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Model Training
# ___

# %% [markdown]
# #### Scale the data using `StandardScaler`

# %%
# Scale using StandardScaler
X_scaler = StandardScaler()
y_scaler = StandardScaler()

X_train_scaled = X_scaler.fit_transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

y_train_scaled = y_scaler.fit_transform(y_train.values.reshape(-1, 1))
y_test_scaled = y_scaler.transform(y_test.values.reshape(-1, 1))

print("X_train_scaled shape:", X_train_scaled.shape)
print("X_test_scaled shape:", X_test_scaled.shape)
print("y_train_scaled shape:", y_train_scaled.shape)
print("y_test_scaled shape:", y_test_scaled.shape)
# Out:
# X_train_scaled shape: (1582783, 10)
# X_test_scaled shape: (395696, 10)
# y_train_scaled shape: (1582783, 1)
# y_test_scaled shape: (395696, 1)

# %%
lin_reg = LinearRegression(
    n_jobs=-1 # Use all processors
)

lin_reg.fit(X_train_scaled, y_train_scaled)
# Out:
# LinearRegression(n_jobs=-1)

# %%
# Predict the target values using the testing data
y_predict_scaled = lin_reg.predict(X_test_scaled)
y_train_predict_scaled = lin_reg.predict(X_train_scaled)

# Unscale the testing data and predictions
y_predict_unscaled = y_scaler.inverse_transform(y_predict_scaled)
y_test_unscaled = y_scaler.inverse_transform(y_test_scaled)

# Unscale the training data and predictions
y_train_unscaled = y_scaler.inverse_transform(y_train_scaled)
y_train_predict_unscaled = y_scaler.inverse_transform(y_train_predict_scaled)

# %%
evaluate_regression_model(
    lin_reg,
    "Linear Regression",
    X_train_scaled,
    y_train_scaled,
    X_test_scaled,
    y_test_scaled,
    y_train_unscaled,
    y_test_unscaled,
    y_train_predict_unscaled,
    y_predict_unscaled
)
# Out:
# ╔═══════════════════════════════════════════════════════════════╗
# ║              Linear Regression Model Evaluation               ║
# ╠═══════════════════════════════════════════════════════════════╣
# ║                                |                              ║
# ║ Training Data Metrics          |                              ║
# ║ Mean Squared Error (Train):    |           16.37386           ║
# ║ Root Mean Squared Error (Tr... |           4.04646            ║
# ║ R-Squared (Train):             |           0.99959            ║
# ║ Adjusted R-Squared (Train):    |           0.99959            ║
# ║ Mean Absolute Error (Train):   |           1.14858            ║
# ║ Mean Absolute Percentage Er... |           1.45881            ║
# ║                                |                              ║
# ║ Testing Data Metrics           |                              ║
# ║ Mean Squared Error (Test):     |           15.53391           ║
# ║ Root Mean Squared Error (Te... |           3.94131            ║
# ║ R-Squared (Test):              |           0.99965            ║
# ║ Adjusted R-Squared (Test):     |           0.99965            ║
# ║ Mean Absolute Error (Test):    |           1.14620            ║
# ║ Mean Absolute Percentage Er... |           1.45554            ║
# ╚═══════════════════════════════════════════════════════════════╝

# %%
cv_scores = cross_val_score(
    LinearRegression(
        n_jobs=-1
    ),
    X_train_scaled,
    y_train_scaled,
    scoring="r2",
    cv=10
)

# %%
evaluate_cross_validation(cv_scores, "Linear Regression")
# Out:
# ╔═══════════════════════════════════════════════════════════════╗
# ║           Linear Regression Cross Validation Scores           ║
# ╠═══════════════════════════════════════════════════════════════╣
# ║ Fold 1:                        |           0.99961            ║
# ║ Fold 2:                        |           0.99960            ║
# ║ Fold 3:                        |           0.99965            ║
# ║ Fold 4:                        |           0.99959            ║
# ║ Fold 5:                        |           0.99951            ║
# ║ Fold 6:                        |           0.99961            ║
# ║ Fold 7:                        |           0.99957            ║
# ║ Fold 8:                        |           0.99956            ║
# ║ Fold 9:                        |           0.99958            ║
# ║ Fold 10:                       |           0.99961            ║
# ║                                |                              ║
# ║ Mean R^2 Score:                |           0.99959            ║
# ║ Standard Deviation:            |           0.00004            ║
# ╚═══════════════════════════════════════════════════════════════╝

# %%
import pickle

# Save model path
model_name = "linear_regression_close.pkl"
model_path = f"../../../models/{model_name}"

# Save the model to a file
with open(model_path, "wb") as file:
    pickle.dump(lin_reg, file)

print(f"Model saved to {model_path}")
# Out:
# Model saved to ../../../models/linear_regression_close.pkl

# %% [markdown]
# ### Predict tomorrows `Adjusted Close`
# ___
# ___
# ___

# %%
def preprocess_todays_data(df, columns_to_drop):
    # Convert 'Date' column to datetime
    df["Date"] = pd.to_datetime(df["Date"])
    
    # Extract year, month, and day from 'Date' column
    df["Year"] = df["Date"].dt.year
    df["Month"] = df["Date"].dt.month
    df["Day"] = df["Date"].dt.day
    
    # Drop specified columns
    df = df.drop(columns=columns_to_drop)
    
    # Set 'Date' and 'Ticker' as the index
    df = df.set_index(["Date", "Ticker"])
    
    # Drop 'Next Day Close' column
    df = df.drop(columns="Next Day Close")
    
    return df

X_to_predict = todays_data.copy()

X_to_predict = preprocess_todays_data(X_to_predict, select_columns_to_drop)

X_to_predict_scaled = X_scaler.transform(X_to_predict)

print("Shape of todays_data_clean_scaled:", X_to_predict_scaled.shape)
X_to_predict_scaled[:5]
# Out:
# Shape of todays_data_clean_scaled: (501, 10)
# array([[ 0.21029221, -0.21050541, -0.50676969, -2.04849203,  0.26539134,
#          0.25211298,  0.28301857,  1.62443221,  1.02782802,  1.06190002],
#        [ 0.71656911,  0.1299215 , -0.38651463,  0.79365625,  0.70975971,
#          0.74646253,  0.76314191,  1.62443221,  1.02782802,  1.06190002],
#        [ 0.49863601, -0.4592691 , -0.79119435, -0.85020721,  0.50742677,
#          0.5520643 ,  0.59719398,  1.62443221,  1.02782802,  1.06190002],
#        [ 0.23249558,  0.58958269, -0.28334676,  0.37484342,  0.24850492,
#          0.22527628,  0.19452787,  1.62443221,  1.02782802,  1.06190002],
#        [ 0.13068012, -0.90781959, -0.64725082,  0.08741691,  0.12313012,
#          0.15204863,  0.17207307,  1.62443221,  1.02782802,  1.06190002]])

# %%
y_to_predict_scaled = lin_reg.predict(X_to_predict_scaled)

y_to_predict_unscaled = y_scaler.inverse_transform(y_to_predict_scaled)

print("Shape of y_to_predict_unscaled:", y_to_predict_unscaled.shape)
y_to_predict_unscaled[:5]
# Out:
# Shape of y_to_predict_unscaled: (501, 1)
# array([[130.28101605],
#        [231.58869119],
#        [187.95440641],
#        [134.72715696],
#        [114.33049032]])

# %%
prediction_df = todays_data.copy()

prediction_df["Next Day Close"] = y_to_predict_unscaled.round(3)

prediction_df = prediction_df[["Date", "Ticker", "Adjusted Close", "Next Day Close"]]

prediction_df = prediction_df.set_index(["Date", "Ticker"])

print("Shape:", prediction_df.shape)
display(prediction_df.head(20))
display(prediction_df.tail(20))
# Out:
# Shape: (501, 2)
#                    Adjusted Close  Next Day Close
# Date       Ticker
# 2024-10-25 A              130.160         130.281
#            AAPL           231.400         231.589
#            ABBV           187.820         187.954
#            ABNB           134.600         134.727
#            ABT            114.240         114.330
#            ACGL           105.280         105.396
#            ACN            360.790         361.005
#            ADBE           483.730         484.730
#            ADI            230.170         230.415
#            ADM             56.570          56.591
#            ADP            287.960         288.142
#            ADSK           286.050         286.088
#            AEE             87.800          87.843
#            AEP             98.180          98.258
#            AES             16.965          16.896
#            AFL            109.710         109.787
#            AIG             76.820          76.888
#            AIZ            191.780         191.935
#            AJG            283.280         283.617
#            AKAM           101.980         102.057
#                    Adjusted Close  Next Day Close
# Date       Ticker
# 2024-10-25 WBD              7.590           7.549
#            WDC             69.455          69.447
#            WEC             97.170          97.225
#            WELL           130.190         130.241
#            WFC             64.520          64.537
#            WM             206.800         207.080
#            WMB             52.510          52.497
#            WMT             82.510          82.560
#            WRB             58.170          58.224
#            WST            307.920         308.129
#            WTW            290.410         290.662
#            WY              31.785          31.783
#            WYNN            97.980          98.019
#            XEL             64.460          64.488
#            XOM            119.510         119.567
#            XYL            130.410         130.573
#            YUM            133.040         133.129
#            ZBH            102.330         102.496
#            ZBRA           359.970         360.426
#            ZTS            179.910         180.158

# %%
# Make index column a regular column
prediction_df.reset_index(inplace=True)

prediction_df
# Out:
#            Date Ticker  Adjusted Close  Next Day Close
# 0    2024-10-25      A          130.16         130.281
# 1    2024-10-25   AAPL          231.40         231.589
# 2    2024-10-25   ABBV          187.82         187.954
# 3    2024-10-25   ABNB          134.60         134.727
# 4    2024-10-25    ABT          114.24         114.330
# ..          ...    ...             ...             ...
# 496  2024-10-25    XYL          130.41         130.573
# 497  2024-10-25    YUM          133.04         133.129
# 498  2024-10-25    ZBH          102.33         102.496
# 499  2024-10-25   ZBRA          359.97         360.426
# 500  2024-10-25    ZTS          179.91         180.158
#
# [501 rows x 4 columns]

# %%
file_name = "lin_reg_predict.zip"
file_path = f"../../../data/raw_data/{file_name}"

save_data(prediction_df, file_path)
# Out:
# ╔═══════════════════════════════════════════════════════════════╗
# ║ File `lin_reg_predict.zip` already exists. Overwriting file.  ║
# ╚═══════════════════════════════════════════════════════════════╝
# ╔═══════════════════════════════════════════════════════════════╗
# ║        File saved and zipped as `lin_reg_predict.zip`         ║
# ╚═══════════════════════════════════════════════════════════════╝
