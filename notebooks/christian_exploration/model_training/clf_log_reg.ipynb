# %%
# Import standard library modules
import sys

# Set the relative path to the project root directory
relative_path_to_root = "../../../"

# Add the project root to the system path for importing in-house modules
sys.path.append(relative_path_to_root)

# Import in-house modules from the 'utilities' package
from utilities import clean_historical_data, check_tickers_for_missing_values
from utilities import calc_vif, calc_p_values, calc_correlation, highlight_vif, highlight_p_values, evaluate_regression_model, evaluate_cross_validation, evaluate_classifier_model
from utilities import load_data, save_data

# %%
# Data manipulation and analysis
import pandas as pd

# Date and time manipulation
from datetime import date

# File and directory manipulation
from pathlib import Path

# Data preprocessing and model selection
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler

# %%
file_name = "sp500_updated_adj_close_with_nas"
file_path = f"../../../data/raw_data/{file_name}"

raw_data = load_data(file_path)
# Out:
# ╔═══════════════════════════════════════════════════════════════╗
# ║File `sp500_updated_adj_close_with_nas.csv.bz2` loaded from `sp500_updated_adj_close_with_nas.zip`║
# ╚═══════════════════════════════════════════════════════════════╝

# %% [markdown]
# #### Inspect Tickers Individually

# %%
# Inspect Cleaned data zeroing in on individual tickers
select_df = raw_data.copy()

select_ticker = select_df["Ticker"] == "AAPL"

select_df[select_ticker].tail(10)
# Out:
#                Date Ticker  Adjusted Close  Today to Tomorrow  \
# 2117227  2024-10-16   AAPL          231.78                1.0
# 2117728  2024-10-17   AAPL          232.15                1.0
# 2118229  2024-10-18   AAPL          235.00                1.0
# 2118730  2024-10-21   AAPL          236.48               -1.0
# 2119231  2024-10-22   AAPL          235.86               -1.0
# 2119732  2024-10-23   AAPL          230.76               -1.0
# 2120233  2024-10-24   AAPL          230.57                1.0
# 2120734  2024-10-25   AAPL          231.41                1.0
# 2121235  2024-10-28   AAPL          233.40                1.0
# 2121736  2024-10-29   AAPL          233.75                NaN
#
#          Yesterday to Today  Next Day Close  Previous Day Close    Return  \
# 2117227                -1.0          232.15              233.85 -0.008852
# 2117728                 1.0          235.00              231.78  0.001596
# 2118229                 1.0          236.48              232.15  0.012277
# 2118730                 1.0          235.86              235.00  0.006298
# 2119231                -1.0          230.76              236.48 -0.002622
# 2119732                -1.0          230.57              235.86 -0.021623
# 2120233                -1.0          231.41              230.76 -0.000823
# 2120734                 1.0          233.40              230.57  0.003643
# 2121235                 1.0          233.75              231.41  0.008599
# 2121736                 1.0             NaN              233.40  0.001500
#
#          Volatility        RSI     SMA_50    SMA_100    SMA_200  Upper Band  \
# 2117227    0.015279  55.546870  224.63441  218.88077  199.03271   233.71204
# 2117728    0.014905  55.662342  225.08586  219.30466  199.26877   234.15703
# 2118229    0.012875  52.767017  225.52460  219.75696  199.52600   235.22388
# 2118730    0.012880  66.655846  225.93440  220.22105  199.80229   236.51566
# 2119231    0.012744  64.702080  226.30100  220.66896  200.07912   237.47850
# 2119732    0.013733  57.298534  226.49080  221.05629  200.30862   237.57504
# 2120233    0.013688  55.555565  226.66780  221.42393  200.53928   237.66525
# 2120734    0.013670  66.385720  226.80160  221.79678  200.76889   237.80995
# 2121235    0.013773  63.837505  226.94860  222.17435  201.01146   237.86389
# 2121736    0.012854  58.716377  227.10580  222.56929  201.25412   238.18172
#
#          Lower Band    Support  Resistance Action
# 2117227   222.44496  209.57742      233.85    buy
# 2117728   222.32797  213.06339      233.85   hold
# 2118229   221.94112  215.99000      235.00   hold
# 2118730   221.65034  216.32000      236.48   sell
# 2119231   221.53650  216.32000      236.48  short
# 2119732   221.87895  216.32000      236.48  short
# 2120233   222.09375  216.32000      236.48    buy
# 2120734   222.31105  216.32000      236.48   hold
# 2121235   222.29712  216.32000      236.48   hold
# 2121736   222.73328  216.32000      236.48    NaN

# %% [markdown]
# ### Data Pre-Processing
# ___

# %%
# Remove where Today to Tomorrow is "O"
value_filter = raw_data["Today to Tomorrow"] == 0

raw_data = raw_data.loc[~value_filter]

raw_data["Today to Tomorrow"].unique()
# Out:
# array([-1.,  1., nan])

# %%
def split_dataset_by_date(raw_data: pd.DataFrame, split_date: str) -> tuple:
    # Filter data by date range
    filter_data_by_date = raw_data["Date"] < split_date
    
    # Create a new dataframe with today's data
    historical_data = raw_data[filter_data_by_date].reset_index(drop=True)
    
    # Create a new dataframe with historical data (excluding today's data)
    predict_data = raw_data[~filter_data_by_date].reset_index(drop=True)
    
    return historical_data, predict_data

# %% [markdown]
# #### Split todays data (For prediction) and historical data (For training)

# %%
# todays_date = "2024-10-25"
split_date = "2024-09-30"

historical_data, predict_data = split_dataset_by_date(raw_data, split_date)

print("Split Date:", split_date)
print("Historical Data Start and End Dates:", historical_data["Date"].min(), historical_data["Date"].max())
print("Predict Data Start and End Dates:", predict_data["Date"].min(), predict_data["Date"].max())
# Out:
# Split Date: 2024-09-30
# Historical Data Start and End Dates: 2008-01-02 2024-09-27
# Predict Data Start and End Dates: 2024-09-30 2024-10-29

# %% [markdown]
# #### Ensure Missing Values on Todays Data is what we are Predicting

# %%
predict_data = clean_historical_data(predict_data)

print("Start Date:", predict_data["Date"].min())
print("End Date:", predict_data["Date"].max())
predict_data.isnull().sum()
# Out:
# Start Date: 2024-09-30
# End Date: 2024-10-29
# Date                    0
# Ticker                  0
# Adjusted Close          0
# Today to Tomorrow     500
# Yesterday to Today      0
# Next Day Close        500
# Previous Day Close      0
# Return                  0
# Volatility              0
# RSI                     0
# SMA_50                  0
# SMA_100                 0
# SMA_200                 0
# Upper Band              0
# Lower Band              0
# Support                 0
# Resistance              0
# Action                500
# dtype: int64

# %% [markdown]
# #### Handle Missing Values (NA's)

# %%
historical_data = clean_historical_data(historical_data)

print("Start Date:", historical_data["Date"].min())
print("End Date:", historical_data["Date"].max())
historical_data.isnull().sum()
# Out:
# Start Date: 2008-01-02
# End Date: 2024-09-27
# Date                  0
# Ticker                0
# Adjusted Close        0
# Today to Tomorrow     0
# Yesterday to Today    0
# Next Day Close        0
# Previous Day Close    0
# Return                0
# Volatility            0
# RSI                   0
# SMA_50                0
# SMA_100               0
# SMA_200               0
# Upper Band            0
# Lower Band            0
# Support               0
# Resistance            0
# Action                0
# dtype: int64

# %%
tickers_no_missing_values, tickers_with_missing_values = check_tickers_for_missing_values(historical_data)
# Out:
# ╔═══════════════════════════════════════════════════════════════╗
# ║          Tickers that do not have any missing values          ║
# ╠═══════════════════════════════════════════════════════════════╣
# ║ Number of unique tickers:      |          499.00000           ║
# ║ Number of tickers with no m... |          499.00000           ║
# ║ Number of tickers with miss... |           0.00000            ║
# ╚═══════════════════════════════════════════════════════════════╝

# %% [markdown]
# ### Exploratory Data Analysis (EDA):
# ___

# %% [markdown]
# #### Predict Data:

# %%
print("Shape:", predict_data.shape)
# Out:
# Shape: (10941, 18)

# %% [markdown]
# #### Historical Data:

# %%
print("Shape:", historical_data.shape)
# Out:
# Shape: (1950560, 18)

# %% [markdown]
# ### Create Multiple Versions of Dataset
# ___

# %%
# Data with dates and without tickers (Set as index for reference)
def prepare_data_v2(main_data: pd.DataFrame) -> pd.DataFrame:
    # Create a copy of the input DataFrame
    df = main_data.copy().reset_index(drop=True)
    
    # Convert the `Date` column to datetime
    df["Date"] = pd.to_datetime(df["Date"])
    
    # Extract year, month, and day from the `Date` column
    df["Year"] = df["Date"].dt.year
    df["Month"] = df["Date"].dt.month
    df["Day"] = df["Date"].dt.day
    
    # Set the index to `Date` and `Ticker`
    df = df.set_index(["Date", "Ticker"])
    
    return df

main_data = prepare_data_v2(historical_data.copy().reset_index(drop=True))

# %% [markdown]
# #### Select which version of the data to work with

# %%
main_data
# Out:
#                    Adjusted Close  Today to Tomorrow  Yesterday to Today  \
# Date       Ticker
# 2008-01-02 A            23.256384               -1.0                -1.0
#            AAPL          5.876340                1.0                -1.0
#            ABT          18.130210               -1.0                -1.0
#            ACGL          7.608889                1.0                -1.0
#            ACN          26.437069               -1.0                 1.0
# ...                           ...                ...                 ...
# 2024-09-27 XYL         134.510000                1.0                 1.0
#            YUM         139.920000               -1.0                 1.0
#            ZBH         107.980000               -1.0                 1.0
#            ZBRA        368.600000                1.0                -1.0
#            ZTS         194.810000                1.0                -1.0
#
#                    Next Day Close  Previous Day Close    Return  Volatility  \
# Date       Ticker
# 2008-01-02 A            23.025742           23.538282 -0.011976    0.015704
#            AAPL          5.879058            5.974059 -0.016357    0.018937
#            ABT          18.019747           18.240658 -0.006055    0.010484
#            ACGL          7.764444            7.816667 -0.026581    0.016022
#            ACN          25.982530           26.415083  0.000832    0.024039
# ...                           ...                 ...       ...         ...
# 2024-09-27 XYL         135.030000          134.130000  0.002833    0.015274
#            YUM         139.710000          138.070000  0.013399    0.012814
#            ZBH         107.950000          107.471130  0.004735    0.020791
#            ZBRA        370.320000          371.240000 -0.007111    0.018034
#            ZTS         195.380000          194.870000 -0.000308    0.009432
#
#                          RSI      SMA_50     SMA_100     SMA_200  Upper Band  \
# Date       Ticker
# 2008-01-02 A       48.827510   23.314175   23.299887   23.564934   24.727250
#            AAPL    59.067307    5.518483    4.939064    4.197630    6.135835
#            ABT     34.677720   18.138460   17.628250   17.709028   19.233109
#            ACGL    45.154190    7.785511    7.878933    7.874161    8.114465
#            ACN     54.812275   26.577984   27.784420   28.471031   28.227203
# ...                      ...         ...         ...         ...         ...
# 2024-09-27 XYL     70.569610  133.008790  135.843140  128.534210  137.803190
#            YUM     66.764175  133.453030  133.806440  133.268300  138.392100
#            ZBH     70.106766  109.309240  110.604160  116.869156  114.414790
#            ZBRA    83.407295  339.336200  326.619300  300.337160  379.808500
#            ZTS     58.244125  185.937800  179.357280  179.692100  198.720290
#
#                    Lower Band     Support  Resistance Action  Year  Month  Day
# Date       Ticker
# 2008-01-02 A        22.540232   21.392033   24.351938  short  2008      1    2
#            AAPL      5.403558    4.637376    6.026840    buy  2008      1    2
#            ABT      18.221806   16.775566   19.134014  short  2008      1    2
#            ACGL      7.378535    7.463333    8.307778    buy  2008      1    2
#            ACN      24.273777   24.765514   29.215666   sell  2008      1    2
# ...                       ...         ...         ...    ...   ...    ...  ...
# 2024-09-27 XYL     126.457810  125.805660  141.154860   hold  2024      9   27
#            YUM     128.823900  125.324680  139.920000   sell  2024      9   27
#            ZBH     100.352870  104.238320  115.912370   sell  2024      9   27
#            ZBRA    314.348500  314.650000  371.240000    buy  2024      9   27
#            ZTS     183.869700  174.820000  196.480000    buy  2024      9   27
#
# [1950560 rows x 19 columns]

# %%
select_data = main_data.copy()

# select_columns_to_drop = ["Action", "Next Day Close"]
select_columns_to_drop = ["Action", "Next Day Close", "Previous Day Close", "SMA_50", "Resistance", "Upper Band", "SMA_200","Next Day Close", "Adjusted Close", "Support", "Lower Band", "SMA_100"]

data = select_data.drop(columns=select_columns_to_drop)

print("Shape:", data.shape)
data.head()
# Out:
# Shape: (1950560, 8)
#                    Today to Tomorrow  Yesterday to Today    Return  \
# Date       Ticker
# 2008-01-02 A                    -1.0                -1.0 -0.011976
#            AAPL                  1.0                -1.0 -0.016357
#            ABT                  -1.0                -1.0 -0.006055
#            ACGL                  1.0                -1.0 -0.026581
#            ACN                  -1.0                 1.0  0.000832
#
#                    Volatility        RSI  Year  Month  Day
# Date       Ticker
# 2008-01-02 A         0.015704  48.827510  2008      1    2
#            AAPL      0.018937  59.067307  2008      1    2
#            ABT       0.010484  34.677720  2008      1    2
#            ACGL      0.016022  45.154190  2008      1    2
#            ACN       0.024039  54.812275  2008      1    2

# %% [markdown]
# ### Split data features `X` and target `y`
# ___

# %%
target = "Today to Tomorrow"

# Split the data into features (X) and target (y)
X = data.drop(columns=target)

y = data[target]

print("Shape of X:", X.shape)
print("Shape of y:", y.shape)
# Out:
# Shape of X: (1950560, 7)
# Shape of y: (1950560,)

# %% [markdown]
# ### Feature Engineering
# ___

# %% [markdown]
# #### Inspect Multicollinearity using VIF

# %%
# Perform correlation matrix of X
calc_correlation(X)
# Out:
# <style type="text/css">
# #T_c7a58_row0_col0, #T_c7a58_row1_col1, #T_c7a58_row2_col2, #T_c7a58_row3_col3, #T_c7a58_row4_col4, #T_c7a58_row5_col5, #T_c7a58_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c7a58_row0_col1 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_c7a58_row0_col2 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_c7a58_row0_col3 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_c7a58_row0_col4, #T_c7a58_row3_col4, #T_c7a58_row5_col2 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_c7a58_row0_col5, #T_c7a58_row1_col5, #T_c7a58_row3_col2, #T_c7a58_row6_col5 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_c7a58_row0_col6, #T_c7a58_row2_col0, #T_c7a58_row2_col3, #T_c7a58_row2_col4, #T_c7a58_row4_col1, #T_c7a58_row4_col2, #T_c7a58_row4_col5, #T_c7a58_row5_col1, #T_c7a58_row6_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_c7a58_row1_col0 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_c7a58_row1_col2 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_c7a58_row1_col3 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_c7a58_row1_col4 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_c7a58_row1_col6, #T_c7a58_row4_col6, #T_c7a58_row5_col6 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_c7a58_row2_col1, #T_c7a58_row4_col0 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_c7a58_row2_col5 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_c7a58_row2_col6, #T_c7a58_row6_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_c7a58_row3_col0 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_c7a58_row3_col1 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_c7a58_row3_col5 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_c7a58_row3_col6, #T_c7a58_row5_col0 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_c7a58_row4_col3 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_c7a58_row5_col3 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_c7a58_row5_col4 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_c7a58_row6_col2, #T_c7a58_row6_col4 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_c7a58_row6_col3 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c7a58">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7a58_level0_col0" class="col_heading level0 col0" >Yesterday to Today</th>
#       <th id="T_c7a58_level0_col1" class="col_heading level0 col1" >Return</th>
#       <th id="T_c7a58_level0_col2" class="col_heading level0 col2" >Volatility</th>
#       <th id="T_c7a58_level0_col3" class="col_heading level0 col3" >RSI</th>
#       <th id="T_c7a58_level0_col4" class="col_heading level0 col4" >Year</th>
#       <th id="T_c7a58_level0_col5" class="col_heading level0 col5" >Month</th>
#       <th id="T_c7a58_level0_col6" class="col_heading level0 col6" >Day</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7a58_level0_row0" class="row_heading level0 row0" >Yesterday to Today</th>
#       <td id="T_c7a58_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_c7a58_row0_col1" class="data row0 col1" >0.633165</td>
#       <td id="T_c7a58_row0_col2" class="data row0 col2" >-0.013552</td>
#       <td id="T_c7a58_row0_col3" class="data row0 col3" >0.202797</td>
#       <td id="T_c7a58_row0_col4" class="data row0 col4" >0.011005</td>
#       <td id="T_c7a58_row0_col5" class="data row0 col5" >0.000123</td>
#       <td id="T_c7a58_row0_col6" class="data row0 col6" >-0.008570</td>
#     </tr>
#     <tr>
#       <th id="T_c7a58_level0_row1" class="row_heading level0 row1" >Return</th>
#       <td id="T_c7a58_row1_col0" class="data row1 col0" >0.633165</td>
#       <td id="T_c7a58_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_c7a58_row1_col2" class="data row1 col2" >0.027243</td>
#       <td id="T_c7a58_row1_col3" class="data row1 col3" >0.215085</td>
#       <td id="T_c7a58_row1_col4" class="data row1 col4" >0.001794</td>
#       <td id="T_c7a58_row1_col5" class="data row1 col5" >0.002930</td>
#       <td id="T_c7a58_row1_col6" class="data row1 col6" >-0.000102</td>
#     </tr>
#     <tr>
#       <th id="T_c7a58_level0_row2" class="row_heading level0 row2" >Volatility</th>
#       <td id="T_c7a58_row2_col0" class="data row2 col0" >-0.013552</td>
#       <td id="T_c7a58_row2_col1" class="data row2 col1" >0.027243</td>
#       <td id="T_c7a58_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_c7a58_row2_col3" class="data row2 col3" >-0.096164</td>
#       <td id="T_c7a58_row2_col4" class="data row2 col4" >-0.137099</td>
#       <td id="T_c7a58_row2_col5" class="data row2 col5" >0.010338</td>
#       <td id="T_c7a58_row2_col6" class="data row2 col6" >-0.003634</td>
#     </tr>
#     <tr>
#       <th id="T_c7a58_level0_row3" class="row_heading level0 row3" >RSI</th>
#       <td id="T_c7a58_row3_col0" class="data row3 col0" >0.202797</td>
#       <td id="T_c7a58_row3_col1" class="data row3 col1" >0.215085</td>
#       <td id="T_c7a58_row3_col2" class="data row3 col2" >-0.096164</td>
#       <td id="T_c7a58_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_c7a58_row3_col4" class="data row3 col4" >0.011103</td>
#       <td id="T_c7a58_row3_col5" class="data row3 col5" >-0.003006</td>
#       <td id="T_c7a58_row3_col6" class="data row3 col6" >0.003873</td>
#     </tr>
#     <tr>
#       <th id="T_c7a58_level0_row4" class="row_heading level0 row4" >Year</th>
#       <td id="T_c7a58_row4_col0" class="data row4 col0" >0.011005</td>
#       <td id="T_c7a58_row4_col1" class="data row4 col1" >0.001794</td>
#       <td id="T_c7a58_row4_col2" class="data row4 col2" >-0.137099</td>
#       <td id="T_c7a58_row4_col3" class="data row4 col3" >0.011103</td>
#       <td id="T_c7a58_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_c7a58_row4_col5" class="data row4 col5" >-0.036902</td>
#       <td id="T_c7a58_row4_col6" class="data row4 col6" >0.000166</td>
#     </tr>
#     <tr>
#       <th id="T_c7a58_level0_row5" class="row_heading level0 row5" >Month</th>
#       <td id="T_c7a58_row5_col0" class="data row5 col0" >0.000123</td>
#       <td id="T_c7a58_row5_col1" class="data row5 col1" >0.002930</td>
#       <td id="T_c7a58_row5_col2" class="data row5 col2" >0.010338</td>
#       <td id="T_c7a58_row5_col3" class="data row5 col3" >-0.003006</td>
#       <td id="T_c7a58_row5_col4" class="data row5 col4" >-0.036902</td>
#       <td id="T_c7a58_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_c7a58_row5_col6" class="data row5 col6" >0.000027</td>
#     </tr>
#     <tr>
#       <th id="T_c7a58_level0_row6" class="row_heading level0 row6" >Day</th>
#       <td id="T_c7a58_row6_col0" class="data row6 col0" >-0.008570</td>
#       <td id="T_c7a58_row6_col1" class="data row6 col1" >-0.000102</td>
#       <td id="T_c7a58_row6_col2" class="data row6 col2" >-0.003634</td>
#       <td id="T_c7a58_row6_col3" class="data row6 col3" >0.003873</td>
#       <td id="T_c7a58_row6_col4" class="data row6 col4" >0.000166</td>
#       <td id="T_c7a58_row6_col5" class="data row6 col5" >0.000027</td>
#       <td id="T_c7a58_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ##### **Note: It is recommended to remove `["Previous Day Close", "Resistance", "Upper Band", "SMA_50", "SMA_200"]` after VIF inspection...**

# %%
# Perform Variance Inflation Factor (VIF) analysis
vif = calc_vif(X)

vif.style.apply(lambda x: highlight_vif(x, threshold=2000))
# Out:
# <style type="text/css">
# #T_3ad28_row0_col0, #T_3ad28_row1_col0, #T_3ad28_row2_col0, #T_3ad28_row3_col0, #T_3ad28_row4_col0, #T_3ad28_row5_col0, #T_3ad28_row6_col0 {
#   background-color: black;
# }
# </style>
# <table id="T_3ad28">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3ad28_level0_col0" class="col_heading level0 col0" >VIF</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ad28_level0_row0" class="row_heading level0 row0" >Yesterday to Today</th>
#       <td id="T_3ad28_row0_col0" class="data row0 col0" >1.687847</td>
#     </tr>
#     <tr>
#       <th id="T_3ad28_level0_row1" class="row_heading level0 row1" >Return</th>
#       <td id="T_3ad28_row1_col0" class="data row1 col0" >1.698659</td>
#     </tr>
#     <tr>
#       <th id="T_3ad28_level0_row2" class="row_heading level0 row2" >Volatility</th>
#       <td id="T_3ad28_row2_col0" class="data row2 col0" >3.159457</td>
#     </tr>
#     <tr>
#       <th id="T_3ad28_level0_row3" class="row_heading level0 row3" >Day</th>
#       <td id="T_3ad28_row3_col0" class="data row3 col0" >4.229707</td>
#     </tr>
#     <tr>
#       <th id="T_3ad28_level0_row4" class="row_heading level0 row4" >Month</th>
#       <td id="T_3ad28_row4_col0" class="data row4 col0" >4.622204</td>
#     </tr>
#     <tr>
#       <th id="T_3ad28_level0_row5" class="row_heading level0 row5" >RSI</th>
#       <td id="T_3ad28_row5_col0" class="data row5 col0" >11.871121</td>
#     </tr>
#     <tr>
#       <th id="T_3ad28_level0_row6" class="row_heading level0 row6" >Year</th>
#       <td id="T_3ad28_row6_col0" class="data row6 col0" >21.632499</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Data Splitting
# ___

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.2, # 80% training and 20% testing
    random_state=42
)

print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (1560448, 7)
# Shape of X_test: (390112, 7)
# Shape of y_train: (1560448,)
# Shape of y_test: (390112,)

# %% [markdown]
# #### Inspect Probability Values `(p-values)`|

# %% [markdown]
# ##### **Note: It is recommended to remove `["Day"]` after p-value inspection...**

# %%
# Check P-Values
p_values, ols_model = calc_p_values(X_train, y_train)

p_values.style.apply(highlight_p_values)
# Out:
# <style type="text/css">
# #T_5dcc6_row0_col0, #T_5dcc6_row1_col0, #T_5dcc6_row2_col0, #T_5dcc6_row3_col0, #T_5dcc6_row4_col0 {
#   background-color: black;
# }
# </style>
# <table id="T_5dcc6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5dcc6_level0_col0" class="col_heading level0 col0" >p_value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5dcc6_level0_row0" class="row_heading level0 row0" >Year</th>
#       <td id="T_5dcc6_row0_col0" class="data row0 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5dcc6_level0_row1" class="row_heading level0 row1" >Volatility</th>
#       <td id="T_5dcc6_row1_col0" class="data row1 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5dcc6_level0_row2" class="row_heading level0 row2" >RSI</th>
#       <td id="T_5dcc6_row2_col0" class="data row2 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5dcc6_level0_row3" class="row_heading level0 row3" >Return</th>
#       <td id="T_5dcc6_row3_col0" class="data row3 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5dcc6_level0_row4" class="row_heading level0 row4" >Yesterday to Today</th>
#       <td id="T_5dcc6_row4_col0" class="data row4 col0" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_5dcc6_level0_row5" class="row_heading level0 row5" >Day</th>
#       <td id="T_5dcc6_row5_col0" class="data row5 col0" >0.349688</td>
#     </tr>
#     <tr>
#       <th id="T_5dcc6_level0_row6" class="row_heading level0 row6" >Month</th>
#       <td id="T_5dcc6_row6_col0" class="data row6 col0" >0.606815</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Model Training
# ___

# %% [markdown]
# #### Scale the data using `StandardScaler`

# %%
# Scale using StandardScaler
X_scaler = StandardScaler()
# y_scaler = StandardScaler()

X_train_scaled = X_scaler.fit_transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# y_train_scaled = y_scaler.fit_transform(y_train.values.reshape(-1, 1))
# y_test_scaled = y_scaler.transform(y_test.values.reshape(-1, 1))

print("X_train_scaled shape:", X_train_scaled.shape)
print("X_test_scaled shape:", X_test_scaled.shape)
# print("y_train_scaled shape:", y_train_scaled.shape)
# print("y_test_scaled shape:", y_test_scaled.shape)
# Out:
# X_train_scaled shape: (1560448, 7)
# X_test_scaled shape: (390112, 7)

# %%
y.value_counts()
# Out:
# Today to Tomorrow
#  1.0    1021992
# -1.0     928568
# Name: count, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

# import grid search
from sklearn.model_selection import GridSearchCV

# Create a logistic regression model
log_reg_model = LogisticRegression()

# Create a dictionary of hyperparameters to search
param_grid = {
    "C": [0.001, 0.01, 0.1, 1, 10, 100, 1000],
    "penalty": ["l1", "l2"],
    "solver": ["liblinear"]
}

# Create grid search
grid_search = GridSearchCV(
    log_reg_model,
    param_grid,
    verbose=3,
    cv=5
)

# Fit the model using the grid search estimator
grid_search.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 14 candidates, totalling 70 fits
# [CV 1/5] END C=0.001, penalty=l1, solver=liblinear;, score=0.526 total time=   1.0s
# [CV 2/5] END C=0.001, penalty=l1, solver=liblinear;, score=0.526 total time=   1.1s
# [CV 3/5] END C=0.001, penalty=l1, solver=liblinear;, score=0.526 total time=   1.1s
# [CV 4/5] END C=0.001, penalty=l1, solver=liblinear;, score=0.526 total time=   0.9s
# [CV 5/5] END C=0.001, penalty=l1, solver=liblinear;, score=0.526 total time=   0.8s
# [CV 1/5] END C=0.001, penalty=l2, solver=liblinear;, score=0.527 total time=   1.1s
# [CV 2/5] END C=0.001, penalty=l2, solver=liblinear;, score=0.526 total time=   1.1s
# [CV 3/5] END C=0.001, penalty=l2, solver=liblinear;, score=0.527 total time=   1.1s
# [CV 4/5] END C=0.001, penalty=l2, solver=liblinear;, score=0.526 total time=   1.1s
# [CV 5/5] END C=0.001, penalty=l2, solver=liblinear;, score=0.526 total time=   1.1s
# [CV 1/5] END C=0.01, penalty=l1, solver=liblinear;, score=0.527 total time=   1.0s
# [CV 2/5] END C=0.01, penalty=l1, solver=liblinear;, score=0.526 total time=   1.0s
# [CV 3/5] END C=0.01, penalty=l1, solver=liblinear;, score=0.527 total time=   1.0s
# [CV 4/5] END C=0.01, penalty=l1, solver=liblinear;, score=0.526 total time=   1.1s
# [CV 5/5] END C=0.01, penalty=l1, solver=liblinear;, score=0.526 total time=   0.9s
# [CV 1/5] END C=0.01, penalty=l2, solver=liblinear;, score=0.527 total time=   1.1s
# [CV 2/5] END C=0.01, penalty=l2, solver=liblinear;, score=0.526 total time=   1.1s
# [CV 3/5] END C=0.01, penalty=l2, solver=liblinear;, score=0.527 total time=   1.1s
# [CV 4/5] END C=0.01, penalty=l2, solver=liblinear;, score=0.526 total time=   1.1s
# [CV 5/5] END C=0.01, penalty=l2, solver=liblinear;, score=0.526 total time=   1.1s
# [CV 1/5] END C=0.1, penalty=l1, solver=liblinear;, score=0.527 total time=   1.1s
# [CV 2/5] END C=0.1, penalty=l1, solver=liblinear;, score=0.526 total time=   1.1s
# [CV 3/5] END C=0.1, penalty=l1, solver=liblinear;, score=0.527 total time=   1.0s
# [CV 4/5] END C=0.1, penalty=l1, solver=liblinear;, score=0.526 total time=   1.1s
# [CV 5/5] END C=0.1, penalty=l1, solver=liblinear;, score=0.526 total time=   0.9s
# [CV 1/5] END C=0.1, penalty=l2, solver=liblinear;, score=0.527 total time=   1.1s
# [CV 2/5] END C=0.1, penalty=l2, solver=liblinear;, score=0.526 total time=   1.1s
# [CV 3/5] END C=0.1, penalty=l2, solver=liblinear;, score=0.527 total time=   1.1s
# [CV 4/5] END C=0.1, penalty=l2, solver=liblinear;, score=0.526 total time=   1.1s
# [CV 5/5] END C=0.1, penalty=l2, solver=liblinear;, score=0.526 total time=   1.1s
# [CV 1/5] END .C=1, penalty=l1, solver=liblinear;, score=0.527 total time=   1.2s
# [CV 2/5] END .C=1, penalty=l1, solver=liblinear;, score=0.526 total time=   1.0s
# [CV 3/5] END .C=1, penalty=l1, solver=liblinear;, score=0.527 total time=   1.0s
# [CV 4/5] END .C=1, penalty=l1, solver=liblinear;, score=0.526 total time=   1.0s
# [CV 5/5] END .C=1, penalty=l1, solver=liblinear;, score=0.526 total time=   1.0s
# [CV 1/5] END .C=1, penalty=l2, solver=liblinear;, score=0.527 total time=   1.1s
# [CV 2/5] END .C=1, penalty=l2, solver=liblinear;, score=0.526 total time=   1.1s
# [CV 3/5] END .C=1, penalty=l2, solver=liblinear;, score=0.527 total time=   1.1s
# [CV 4/5] END .C=1, penalty=l2, solver=liblinear;, score=0.526 total time=   1.1s
# [CV 5/5] END .C=1, penalty=l2, solver=liblinear;, score=0.526 total time=   1.1s
# [CV 1/5] END C=10, penalty=l1, solver=liblinear;, score=0.527 total time=   1.0s
# [CV 2/5] END C=10, penalty=l1, solver=liblinear;, score=0.526 total time=   0.9s
# [CV 3/5] END C=10, penalty=l1, solver=liblinear;, score=0.527 total time=   1.0s
# [CV 4/5] END C=10, penalty=l1, solver=liblinear;, score=0.526 total time=   0.9s
# [CV 5/5] END C=10, penalty=l1, solver=liblinear;, score=0.526 total time=   1.0s
# [CV 1/5] END C=10, penalty=l2, solver=liblinear;, score=0.527 total time=   1.1s
# [CV 2/5] END C=10, penalty=l2, solver=liblinear;, score=0.526 total time=   1.1s
# [CV 3/5] END C=10, penalty=l2, solver=liblinear;, score=0.527 total time=   1.1s
# [CV 4/5] END C=10, penalty=l2, solver=liblinear;, score=0.526 total time=   1.0s
# [CV 5/5] END C=10, penalty=l2, solver=liblinear;, score=0.526 total time=   1.1s
# [CV 1/5] END C=100, penalty=l1, solver=liblinear;, score=0.527 total time=   1.0s
# [CV 2/5] END C=100, penalty=l1, solver=liblinear;, score=0.526 total time=   0.9s
# [CV 3/5] END C=100, penalty=l1, solver=liblinear;, score=0.527 total time=   1.0s
# [CV 4/5] END C=100, penalty=l1, solver=liblinear;, score=0.526 total time=   1.0s
# [CV 5/5] END C=100, penalty=l1, solver=liblinear;, score=0.526 total time=   1.1s
# [CV 1/5] END C=100, penalty=l2, solver=liblinear;, score=0.527 total time=   1.1s
# [CV 2/5] END C=100, penalty=l2, solver=liblinear;, score=0.526 total time=   1.1s
# [CV 3/5] END C=100, penalty=l2, solver=liblinear;, score=0.527 total time=   1.1s
# [CV 4/5] END C=100, penalty=l2, solver=liblinear;, score=0.526 total time=   1.1s
# [CV 5/5] END C=100, penalty=l2, solver=liblinear;, score=0.526 total time=   1.1s
# [CV 1/5] END C=1000, penalty=l1, solver=liblinear;, score=0.527 total time=   1.0s
# [CV 2/5] END C=1000, penalty=l1, solver=liblinear;, score=0.526 total time=   1.0s
# [CV 3/5] END C=1000, penalty=l1, solver=liblinear;, score=0.527 total time=   1.0s
# [CV 4/5] END C=1000, penalty=l1, solver=liblinear;, score=0.526 total time=   1.0s
# [CV 5/5] END C=1000, penalty=l1, solver=liblinear;, score=0.526 total time=   1.1s
# [CV 1/5] END C=1000, penalty=l2, solver=liblinear;, score=0.527 total time=   1.1s
# [CV 2/5] END C=1000, penalty=l2, solver=liblinear;, score=0.526 total time=   1.1s
# [CV 3/5] END C=1000, penalty=l2, solver=liblinear;, score=0.527 total time=   1.1s
# [CV 4/5] END C=1000, penalty=l2, solver=liblinear;, score=0.526 total time=   1.1s
# [CV 5/5] END C=1000, penalty=l2, solver=liblinear;, score=0.526 total time=   1.1s
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'C': [0.001, 0.01, 0.1, 1, 10, 100, 1000],
#                          'penalty': ['l1', 'l2'], 'solver': ['liblinear']},
#              verbose=3)

# %%
import json

print(json.dumps(grid_search.best_params_, indent=4))
# Out:
# {
#     "C": 0.01,
#     "penalty": "l1",
#     "solver": "liblinear"
# }

# %%
best_xgb_model = grid_search.best_estimator_

# %%
# Predict the target values using the testing data
y_test_predict = best_xgb_model.predict(X_test_scaled)
y_train_predict = best_xgb_model.predict(X_train_scaled)

# %%
confusion_train, confusion_test = evaluate_classifier_model(
    "Logistic Regression",
    y_train,
    y_test,
    y_train_predict,
    y_test_predict
)
# Out:
# ╔═══════════════════════════════════════════════════════════════╗
# ║             Logistic Regression Model Evaluation              ║
# ╠═══════════════════════════════════════════════════════════════╣
# ║                                |                              ║
# ║ Training Data Metrics          |                              ║
# ║ Accuracy (Train):              |           0.52640            ║
# ║ Precision (Train):             |           0.52509            ║
# ║ Recall (Train):                |           0.52640            ║
# ║ F1 Score (Train):              |           0.40131            ║
# ║                                |                              ║
# ║ Testing Data Metrics           |                              ║
# ║ Accuracy (Test):               |           0.52553            ║
# ║ Precision (Test):              |           0.52560            ║
# ║ Recall (Test):                 |           0.52553            ║
# ║ F1 Score (Test):               |           0.40034            ║
# ╚═══════════════════════════════════════════════════════════════╝

# %%
import numpy as np

classes = np.unique(y_train)
print("Class order:", classes)
# Out:
# Class order: [-1.  1.]

# %%
df_confusion_train = pd.DataFrame(
    confusion_train,
    index=["Actual -1", "Actual 1"],
    columns=["Predicted -1", "Predicted 1"]
)

df_confusion_train
# Out:
#            Predicted -1  Predicted 1
# Actual -1         38847       703670
# Actual 1          35361       782570

# %%
df_confusion_test = pd.DataFrame(
    confusion_test,
    index=["Actual -1", "Actual 1"],
    columns=["Predicted -1", "Predicted 1"]
)

df_confusion_test
# Out:
#            Predicted -1  Predicted 1
# Actual -1          9750       176301
# Actual 1           8797       195264

# %%
cv_scores = cross_val_score(
    log_reg_model,
    X_train_scaled,
    y_train,  # Use the original y_train with values 1, -1, and 0
    scoring="accuracy",  # Use accuracy for classification
    cv=5
)

# %%
evaluate_cross_validation(cv_scores, "Logistic Regression")
# Out:
# ╔═══════════════════════════════════════════════════════════════╗
# ║          Logistic Regression Cross Validation Scores          ║
# ╠═══════════════════════════════════════════════════════════════╣
# ║ Fold 1:                        |           0.52651            ║
# ║ Fold 2:                        |           0.52609            ║
# ║ Fold 3:                        |           0.52676            ║
# ║ Fold 4:                        |           0.52640            ║
# ║ Fold 5:                        |           0.52612            ║
# ║                                |                              ║
# ║ Mean Score:                    |           0.52638            ║
# ║ Standard Deviation:            |           0.00025            ║
# ╚═══════════════════════════════════════════════════════════════╝

# %%
import pickle

# Save model path
model_name = "logistic_regression_model.pkl"
model_path = f"../../../models/{model_name}"

# Save the model to a file
with open(model_path, "wb") as file:
    pickle.dump(log_reg_model, file)

print(f"Model saved to {model_path}")
# Out:
# Model saved to ../../../models/logistic_regression_model.pkl

# %% [markdown]
# ### Predict `Adjusted Close`
# ___
# ___
# ___

# %%
def preprocess_predict_data(df, columns_to_drop):
    # Convert 'Date' column to datetime
    df["Date"] = pd.to_datetime(df["Date"])
    
    # Extract year, month, and day from 'Date' column
    df["Year"] = df["Date"].dt.year
    df["Month"] = df["Date"].dt.month
    df["Day"] = df["Date"].dt.day
    
    # Drop specified columns
    df = df.drop(columns=columns_to_drop)
    
    # Set 'Date' and 'Ticker' as the index
    df = df.set_index(["Date", "Ticker"])
    
    df = df.drop(columns="Today to Tomorrow")
    
    return df

# %%
# Make a copy of the data we will use to predict
X_to_predict = predict_data.copy()

# Preprocess the data for prediction
X_to_predict = preprocess_predict_data(X_to_predict, select_columns_to_drop)

# Scale the data using the StandardScaler
X_to_predict_scaled = X_scaler.transform(X_to_predict)

print("Shape of predict data:", X_to_predict_scaled.shape)
X_to_predict_scaled
# Out:
# Shape of predict data: (10941, 7)
# array([[ 0.95662083,  0.09544006, -0.19318623, ...,  1.63587341,
#          0.73919198,  1.63151544],
#        [ 0.95662083,  0.98654678, -0.32567388, ...,  1.63587341,
#          0.73919198,  1.63151544],
#        [ 0.95662083,  0.5834852 , -0.60550521, ...,  1.63587341,
#          0.73919198,  1.63151544],
#        ...,
#        [ 0.95662083,  0.08947738, -0.59636822, ...,  1.63587341,
#          1.03280235,  1.51723724],
#        [ 0.95662083,  2.52843059, -0.1947437 , ...,  1.63587341,
#          1.03280235,  1.51723724],
#        [-1.05228825, -0.39333869, -0.42524934, ...,  1.63587341,
#          1.03280235,  1.51723724]])

# %%
# Predict the target values using the testing data
y_to_predict = best_xgb_model.predict(X_to_predict_scaled)

print("Shape of y_to_predict:", y_to_predict.shape)
y_to_predict[:5]
# Out:
# Shape of y_to_predict: (10941,)
# array([1., 1., 1., 1., 1.])

# %%
# Create a copy of the predict data so we may add the predictions
prediction_df = predict_data.copy()

# Add the predictions to the predict data made by the model
prediction_df["Pred Today to Tomorrow"] = y_to_predict

# Make a column "Correct Prediction" to check if the prediction is correct by comparing the actual value and the predicted value
prediction_df["Is Correct Prediction"] = prediction_df["Today to Tomorrow"] == prediction_df["Pred Today to Tomorrow"]

# Select the columns to keep
prediction_df = prediction_df[
    [
        'Date',
        'Ticker',
        'Adjusted Close',
        'Today to Tomorrow',
        'Pred Today to Tomorrow',
        'Is Correct Prediction'
    ]
]

# Drop rows with missing values
prediction_df.dropna(inplace=True)

# Set the index to 'Date' and 'Ticker' to better group the data
prediction_df = prediction_df.set_index(["Date", "Ticker"])

print("Shape:", prediction_df.shape)
display(prediction_df.head())
display(prediction_df.tail())
# Out:
# Shape: (10441, 4)
#                    Adjusted Close  Today to Tomorrow  Pred Today to Tomorrow  \
# Date       Ticker
# 2024-09-30 A           148.244000               -1.0                     1.0
#            AAPL        233.000000               -1.0                     1.0
#            ABBV        195.915500               -1.0                     1.0
#            ABNB        126.810000               -1.0                     1.0
#            ABT         113.475204               -1.0                     1.0
#
#                    Is Correct Prediction
# Date       Ticker
# 2024-09-30 A                       False
#            AAPL                    False
#            ABBV                    False
#            ABNB                    False
#            ABT                     False
#                    Adjusted Close  Today to Tomorrow  Pred Today to Tomorrow  \
# Date       Ticker
# 2024-10-28 XYL             130.79               -1.0                     1.0
#            YUM             134.86               -1.0                     1.0
#            ZBH             103.60                1.0                     1.0
#            ZBRA            363.58                1.0                     1.0
#            ZTS             182.76               -1.0                     1.0
#
#                    Is Correct Prediction
# Date       Ticker
# 2024-10-28 XYL                     False
#            YUM                     False
#            ZBH                      True
#            ZBRA                     True
#            ZTS                     False

# %%
prediction_df["Is Correct Prediction"].value_counts()
# Out:
# Is Correct Prediction
# False    5296
# True     5145
# Name: count, dtype: int64

# %%
# Inspect Cleaned data zeroing in on individual tickers
select_df = prediction_df.copy().reset_index()

select_ticker = select_df["Ticker"] == "AAPL"

display(select_df[select_ticker].set_index(["Date", "Ticker"])["Is Correct Prediction"].value_counts())
select_df[select_ticker].set_index(["Date", "Ticker"]).tail()
# Out:
# Is Correct Prediction
# True     12
# False     9
# Name: count, dtype: int64
#                    Adjusted Close  Today to Tomorrow  Pred Today to Tomorrow  \
# Date       Ticker
# 2024-10-22 AAPL            235.86               -1.0                     1.0
# 2024-10-23 AAPL            230.76               -1.0                     1.0
# 2024-10-24 AAPL            230.57                1.0                     1.0
# 2024-10-25 AAPL            231.41                1.0                     1.0
# 2024-10-28 AAPL            233.40                1.0                     1.0
#
#                    Is Correct Prediction
# Date       Ticker
# 2024-10-22 AAPL                    False
# 2024-10-23 AAPL                    False
# 2024-10-24 AAPL                     True
# 2024-10-25 AAPL                     True
# 2024-10-28 AAPL                     True

# %%
# Make index column a regular column
prediction_df.reset_index(inplace=True)

prediction_df
# Out:
#              Date Ticker  Adjusted Close  Today to Tomorrow  \
# 0      2024-09-30      A      148.244000               -1.0
# 1      2024-09-30   AAPL      233.000000               -1.0
# 2      2024-09-30   ABBV      195.915500               -1.0
# 3      2024-09-30   ABNB      126.810000               -1.0
# 4      2024-09-30    ABT      113.475204               -1.0
# ...           ...    ...             ...                ...
# 10436  2024-10-28    XYL      130.790000               -1.0
# 10437  2024-10-28    YUM      134.860000               -1.0
# 10438  2024-10-28    ZBH      103.600000                1.0
# 10439  2024-10-28   ZBRA      363.580000                1.0
# 10440  2024-10-28    ZTS      182.760000               -1.0
#
#        Pred Today to Tomorrow  Is Correct Prediction
# 0                         1.0                  False
# 1                         1.0                  False
# 2                         1.0                  False
# 3                         1.0                  False
# 4                         1.0                  False
# ...                       ...                    ...
# 10436                     1.0                  False
# 10437                     1.0                  False
# 10438                     1.0                   True
# 10439                     1.0                   True
# 10440                     1.0                  False
#
# [10441 rows x 6 columns]

# %%
file_name = "log_reg_predict.zip"
file_path = f"../../../data/raw_data/{file_name}"

save_data(prediction_df, file_path)
# Out:
# ╔═══════════════════════════════════════════════════════════════╗
# ║ File `log_reg_predict.zip` already exists. Overwriting file.  ║
# ╚═══════════════════════════════════════════════════════════════╝
# ╔═══════════════════════════════════════════════════════════════╗
# ║        File saved and zipped as `log_reg_predict.zip`         ║
# ╚═══════════════════════════════════════════════════════════════╝
