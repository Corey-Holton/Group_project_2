# %%
# Import required dependencies
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.svm import SVR 
from pathlib import Path

# %%
# Import data
file_path = Path("Resources/sp500_adj_close_raw.csv")
df = pd.read_csv(file_path)
df.head()
# Out:
#                         Date Ticker  Adjusted Close    Return  Volatility  \
# 0  2008-01-01 19:00:00-05:00      A       23.256388 -0.009917    0.015704
# 1  2008-01-02 19:00:00-05:00      A       23.025743 -0.032554    0.015803
# 2  2008-01-03 19:00:00-05:00      A       22.276165  0.016393    0.017117
# 3  2008-01-06 19:00:00-05:00      A       22.641346 -0.001415    0.017437
# 4  2008-01-07 19:00:00-05:00      A       22.609310  0.002550    0.017388
#
#          RSI     SMA_50    SMA_100    SMA_200  Upper Band  Lower Band  \
# 0  48.827595  23.314174  23.299887  23.564933   24.727251   22.540232
# 1  41.773996  23.305717  23.301104  23.577362   24.694885   22.473933
# 2  36.363704  23.272915  23.291110  23.585947   24.694963   22.277170
# 3  43.899469  23.252926  23.284767  23.594757   24.601660   22.203257
# 4  48.948117  23.240753  23.303347  23.601388   24.476692   22.153963
#
#      Support  Resistance Action
# 0  21.392029   24.351934  short
# 1  21.392029   24.351934  short
# 2  21.392029   24.351934    buy
# 3  21.392029   24.351934   sell
# 4  21.392029   24.351934    buy

# %%
# Split the data into training and testing sets
# Get the target variable (the "Occupancy" column)
y = df["Return"]

# %%
# Get the features (everything except the "Occupancy" column)
X = df.copy()
X = X.drop(columns=["Return", "Date", "Ticker", "Action"])
X.head()
# Out:
#    Adjusted Close  Volatility        RSI     SMA_50    SMA_100    SMA_200  \
# 0       23.256388    0.015704  48.827595  23.314174  23.299887  23.564933
# 1       23.025743    0.015803  41.773996  23.305717  23.301104  23.577362
# 2       22.276165    0.017117  36.363704  23.272915  23.291110  23.585947
# 3       22.641346    0.017437  43.899469  23.252926  23.284767  23.594757
# 4       22.609310    0.017388  48.948117  23.240753  23.303347  23.601388
#
#    Upper Band  Lower Band    Support  Resistance
# 0   24.727251   22.540232  21.392029   24.351934
# 1   24.694885   22.473933  21.392029   24.351934
# 2   24.694963   22.277170  21.392029   24.351934
# 3   24.601660   22.203257  21.392029   24.351934
# 4   24.476692   22.153963  21.392029   24.351934

# %%
# Split data into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# Model and Fit to a Support Vector Machine

# %%
# Create the support vector machine classifier model with a 'linear' kernel
model = SVR(kernel='linear')

# %%
# Fit the model to the training data
model.fit(X_train, y_train)

# %%
# Validate the model by checking the model accuracy with model.score
print('Train Accuracy: %.3f' % model.score(X_train, y_train))
print('Test Accuracy: %.3f' % model.score(X_test, y_test))

# %%
# Predicting the Testing Labels
# Make and save testing predictions with the saved SVM model using the testing data
testing_predictions = model.predict(X_test)

# Review the predictions
testing_predictions

# %%
# Evaluate the Model
# Display the accuracy score for the testing dataset
accuracy_score(y_test, testing_predictions)
